# %% [markdown]
# Mount Dataset

# %%
# !wget https://d17h27t6h515a5.cloudfront.net/topher/2017/February/5898cd6f_traffic-signs-data/traffic-signs-data.zip
# !unzip traffic-signs-data.zip
# Out:
# --2021-03-09 08:08:59--  https://d17h27t6h515a5.cloudfront.net/topher/2017/February/5898cd6f_traffic-signs-data/traffic-signs-data.zip
# Resolving d17h27t6h515a5.cloudfront.net (d17h27t6h515a5.cloudfront.net)... 54.192.137.60, 54.192.137.216, 54.192.137.17, ...
# Connecting to d17h27t6h515a5.cloudfront.net (d17h27t6h515a5.cloudfront.net)|54.192.137.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 123524425 (118M) [application/zip]
# Saving to: ‘traffic-signs-data.zip.6’
#
# traffic-signs-data. 100%[===================>] 117.80M   271MB/s    in 0.4s
#
# 2021-03-09 08:09:00 (271 MB/s) - ‘traffic-signs-data.zip.6’ saved [123524425/123524425]
#
# Archive:  traffic-signs-data.zip
# replace test.p? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# Add libraries and functions

# %%
import pickle
import csv
import os
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2
from skimage.filters import rank
from sklearn.utils import shuffle
import skimage.morphology as morp

import torch
from torch.optim.lr_scheduler import StepLR, ExponentialLR
from torch.utils.data import TensorDataset, DataLoader, Dataset, WeightedRandomSampler
import torchvision.models as models
import torchvision.transforms as transforms
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, roc_auc_score
from torch.autograd import Variable

class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean
        
    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean
    
    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)

def calc_gradient_penalty(x, y_pred_sum):
    gradients = torch.autograd.grad(
        outputs=y_pred_sum,
        inputs=x,
        grad_outputs=torch.ones_like(y_pred_sum),
        create_graph=True,
        retain_graph=True,
    )[0]

    gradients = gradients.flatten(start_dim=1)

    # L2 norm
    grad_norm = gradients.norm(2, dim=1)

    # Two sided penalty
    gradient_penalty = ((grad_norm - 1) ** 2).mean()

    return gradient_penalty

# %% [markdown]
# Open the dataset

# %%
training_file = "train.p"
validation_file= "valid.p"
testing_file = "test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

# %% [markdown]
# Dataset parameters

# %%
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# Number of training examples
n_train = X_train.shape[0]

# Number of testing examples
n_test = X_test.shape[0]

# Number of validation examples.
n_validation = X_valid.shape[0]

# What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))


print("Number of training examples: ", n_train)
print("Number of testing examples: ", n_test)
print("Number of validation examples: ", n_validation)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples:  34799
# Number of testing examples:  12630
# Number of validation examples:  4410
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# Classes included

# %%
signs = """Speed limit (20km/h)
Speed limit (30km/h)
Speed limit (50km/h)
Speed limit (60km/h)
Speed limit (70km/h)
Speed limit (80km/h)
End of speed limit (80km/h)
Speed limit (100km/h)
Speed limit (120km/h)
No passing
No passing for vehicles over 3.5 metric tons
Right-of-way at the next intersection
Priority road
Yield
Stop
No vehicles
Vehicles over 3.5 metric tons prohibited
No entry
General caution
Dangerous curve to the left
Dangerous curve to the right
Double curve
Bumpy road
Slippery road
Road narrows on the right
Road work
Traffic signals
Pedestrians
Children crossing
Bicycles crossing
Beware of ice/snow
Wild animals crossing
End of all speed and passing limits
Turn right ahead
Turn left ahead
Ahead only
Go straight or right
Go straight or left
Keep right
Keep left
Roundabout mandatory
End of no passing
End of no passing by vehicles over 3.5 metric tons""".split('\n')

# %% [markdown]
# Dataset exploration

# %%
def list_images(dataset, dataset_y, ylabel="", cmap=None):
    """
    Display a list of images in a single figure with matplotlib.
        Parameters:
            images: An np.array compatible with plt.imshow.
            lanel (Default = No label): A string to be used as a label for each image.
            cmap (Default = None): Used to display gray images.
    """
    plt.figure(figsize=(15, 16))
    for i in range(6):
        plt.subplot(1, 6, i+1)
        indx = random.randint(0, len(dataset))
        #Use gray scale color map if there is only one channel
        cmap = 'gray' if len(dataset[indx].shape) == 2 else cmap
        plt.imshow(dataset[indx], cmap = cmap)
        plt.xlabel(signs[dataset_y[indx]])
        plt.ylabel(ylabel)
        plt.xticks([])
        plt.yticks([])
    plt.tight_layout(pad=0, h_pad=0, w_pad=0)
    plt.show()
# Plotting sample examples
list_images(X_train, y_train, "Training example")
list_images(X_test, y_test, "Testing example")
list_images(X_valid, y_valid, "Validation example")

# %% [markdown]
# Hyperparameters

# %%
n_epochs = 30

batchsize = 64

# %% [markdown]
# Pre-processing

# %%
def gray_scale(image):
    """
    Convert images to gray scale.
        Parameters:
            image: An np.array compatible with plt.imshow.
    """
    return cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

def local_histo_equalize(image):
    """
    Apply local histogram equalization to grayscale images.
        Parameters:
            image: A grayscale image.
    """
    kernel = morp.disk(30)
    img_local = rank.equalize(image, selem=kernel)
    return img_local
def image_normalize(image):
    """
    Normalize images to [0, 1] scale.
        Parameters:
            image: An np.array compatible with plt.imshow.
    """
    image = np.divide(image, 255)
    return image
def preprocess(X_train, y_train):
  print(X_train.shape)
  X_train, y_train = shuffle(X_train, y_train)
  gray_images = np.array(list(map(gray_scale, X_train)))
  equalized_images =  np.array(list(map(local_histo_equalize, gray_images)))
  X_train  = np.array(list(map(image_normalize, equalized_images)))
 
  return X_train, y_train


X_train = image_normalize(X_train)
X_valid = image_normalize(X_valid)
X_test = image_normalize(X_test)
#X_train, y_train = preprocess(X_train, y_train)
#X_valid, y_valid = preprocess(X_valid, y_valid)
#X_test, y_test = preprocess(X_test, y_test)
list_images(X_train, y_train)

# %% [markdown]
# Transforms

# %%
data_flip = transforms.Compose([
     transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomVerticalFlip(p=0.5),
     transforms.Normalize(0,1)
     #AddGaussianNoise(0., 10/255)
])
test_transform = transforms.Compose([
     transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])


# Resize, normalize and jitter image brightness
data_jitter_brightness = transforms.Compose([
	  transforms.Resize((32, 32)),
    transforms.ColorJitter(brightness=5),
    transforms.Normalize(0,1)
])


# Resize, normalize and rotate image
data_rotate = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomRotation(15),
    transforms.Normalize(0,1)
])


# Resize, normalize and shear image
data_shear = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomAffine(degrees = 15,shear=2),
    transforms.Normalize(0,1)
])

# Resize, normalize and translate image
data_translate = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomAffine(degrees = 15,translate=(0.1,0.1)),
    transforms.Normalize(0,1)
])

# Resize, normalize and crop image 
data_center = transforms.Compose([
	  transforms.Resize((36, 36)),
    transforms.CenterCrop(32),
    transforms.Normalize(0,1)
])
# Resize, normalize and jitter image saturation
data_jitter_saturation = transforms.Compose([
	  transforms.Resize((32, 32)),
    transforms.ColorJitter(saturation=5),
    transforms.Normalize(0,1)
])

# Resize, normalize and jitter image contrast
data_jitter_contrast = transforms.Compose([
	  transforms.Resize((32, 32)),
    transforms.ColorJitter(contrast=5),
    transforms.Normalize(0,1)
    ])

# Resize, normalize and jitter image hues
data_jitter_hue = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.ColorJitter(hue=0.4),
    transforms.Normalize(0,1)
])


class PyTorchImageDataset(Dataset):
    def __init__(self, image_list, labels, transforms=None):
        self.image_list = torch.Tensor(np.rollaxis(image_list.reshape(-1,32,32,3),3,1) )
        self.labels = torch.Tensor(labels)
        self.transforms = transforms
         
    def __len__(self):
        return (len(self.image_list))
    
    def __getitem__(self, i):
        image = self.image_list[i]
        if self.transforms is not None:
            image = self.transforms(image)
        return (image,self.labels[i])

# %% [markdown]
# Making the dataset and loaders

# %%
train_ds = PyTorchImageDataset(X_train,y_train, transforms = test_transform)
#torch.utils.data.ConcatDataset([#PyTorchImageDataset(X_train,y_train, transforms = data_jitter_brightness),
                                           #PyTorchImageDataset(X_train,y_train, transforms = data_rotate),
                                           #PyTorchImageDataset(X_train,y_train, transforms = data_flip),
                                           #PyTorchImageDataset(X_train,y_train, transforms = data_center),
                                           #PyTorchImageDataset(X_train,y_train, transforms = data_translate),
                                           #yTorchImageDataset(X_train,y_train, transforms = data_shear),
                                           #PyTorchImageDataset(X_train,y_train, transforms = test_transform)])
test_ds = PyTorchImageDataset(X_test,y_test, transforms = test_transform)
val_ds = PyTorchImageDataset(X_valid,y_valid, transforms = test_transform)


class_sample_count = np.array(
    [len(np.where(y_train == t)[0]) for t in np.unique(y_train)])
weight = 1. / class_sample_count
samples_weight = np.array([weight[t] for t in y_train])
samples_weight = torch.from_numpy(samples_weight)
samples_weigth = samples_weight.double()
sampler = WeightedRandomSampler(samples_weight, len(samples_weight))

train_loader = DataLoader(train_ds,batchsize,shuffle = True);
test_loader = DataLoader(test_ds,X_test.shape[0]);
val_loader = DataLoader(val_ds,X_valid.shape[0]);

# %% [markdown]
# MODEL

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.checkpoint import checkpoint

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        # CNN layers
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3),
            nn.BatchNorm2d(32),
            # inplace=True -> сохранить немного памяти
            nn.LeakyReLU(),
            
            nn.Conv2d(32, 32, kernel_size=3),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(),
            
            nn.Conv2d(32, 32, kernel_size=5, stride=2, padding=14),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(),
            
            nn.MaxPool2d(2, 2),
            nn.Dropout2d(0.25)
        )
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(64, 64, kernel_size=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(64, 64, kernel_size=5, stride=2, padding=6),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(2, 2),
            nn.Dropout2d(0.25)
        )
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=4),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Dropout2d(0.25)
        )
        
        self.fc = nn.Sequential(
            nn.Linear(128 * 1 * 1, 128),
            
            #nn.Linear(64, n_classes),

#             хуже????
#             nn.Softmax(dim=1)
        )

        self.localization = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
            )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(10 * 4 * 4, 32),
            nn.ReLU(True),
            nn.Linear(32, 3 * 2),
            )
        
        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))


    # Spatial transformer network forward function
    def stn(self, x):
        xs = self.localization(x)
        xs = xs.view(-1, 10 * 4 * 4)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)
        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)
        return x

    def compute_features(self, x):
        # transform the input
        x = self.stn(x)
        self.datain = x
        # Perform forward pass
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        #print(x.shape)
        x = x.view(-1, 128 * 1 * 1)
        
        x = self.fc(x)
        return x



class CNN_DUQ(Net):
    def __init__(
        self,
        input_size,
        num_classes,
        centroid_size,
        model_output_size,
        length_scale,
        gamma,
        input_dep_ls=False
    ):
        super().__init__()

        self.gamma = gamma
        self.input_dep_ls=input_dep_ls

        self.W = nn.Parameter(
            torch.zeros(centroid_size, num_classes, model_output_size)
        )
        nn.init.kaiming_normal_(self.W, nonlinearity="relu")


        self.register_buffer("N", torch.zeros(num_classes) + 13)
        self.register_buffer(
            "m", torch.normal(torch.zeros(centroid_size, num_classes), 0.05)
        )
        self.m = self.m * self.N
        
        if input_dep_ls:
            self.sigmann=nn.Linear(model_output_size,1)
        self.sigma = length_scale

    def rbf(self, z):
    
        if self.input_dep_ls:
            self.sigma = torch.sigmoid(self.sigmann(z))+0.01
            
        z = torch.einsum("ij,mnj->imn", z, self.W)

        embeddings = self.m / self.N.unsqueeze(0)

        diff = z - embeddings.unsqueeze(0)
        diff = (diff ** 2).mean(1).div(2 * self.sigma ** 2).mul(-1).exp()

        return diff

    def update_embeddings(self, x, y):
        self.N = self.gamma * self.N + (1 - self.gamma) * y.sum(0)

        z = self.compute_features(x)

        z = torch.einsum("ij,mnj->imn", z, self.W)
        embedding_sum = torch.einsum("ijk,ik->jk", z, y)

        self.m = self.gamma * self.m + (1 - self.gamma) * embedding_sum

    def forward(self, x):
        z = self.compute_features(x)
        y_pred = self.rbf(z)

        return y_pred

length_scale = 2
input_size = 32
num_classes = 43
output_size = 128
embedding_size = 100
learnable_length_scale = False #Learnable length scale
gamma = 0.999
input_dep_ls = True
torch.cuda.empty_cache()
network =[]
network = CNN_DUQ(input_size,num_classes,embedding_size,output_size,length_scale,gamma,input_dep_ls).float().cuda()

# %% [markdown]
# Optimizer and Loss

# %%
learning_rate = 0.001
momentum = 0.1
weight_decay = 0.0001
network.train()
optimizer = optim.Adam(filter(lambda p: p.requires_grad,network.parameters()),lr=learning_rate,weight_decay=weight_decay)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min',patience=2,factor=0.5,verbose=True)
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# Training and testing

# %%
log_interval = 20
lm = 0.1

def train(epoch):

  torch.cuda.empty_cache()
  network.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    torch.cuda.empty_cache()
    network.train()
    data, target = Variable(data), Variable(target)
    data=data.cuda(); target=target.cuda();

    optimizer.zero_grad()
    output = network(data)
    datain = network.datain
    loss = 10*F.binary_cross_entropy(output, F.one_hot(target.long(),43).float()) + lm*calc_gradient_penalty(datain,output.sum(1))
    loss.backward()
    optimizer.step()
    with torch.no_grad():
      network.eval()
      network.update_embeddings(data,F.one_hot(target.long(),43).float())
    
    if batch_idx % log_interval == 0:
      correct = output.argmax(1).long().eq(target.long().data.view_as(output.argmax(1).long())).sum()
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} \t Correct: {:.2f}'.format(
        epoch, batch_idx * len(data), len(train_loader.dataset),
        100. * batch_idx / len(train_loader), loss.item(), 100*correct/len(data)))
      
      #torch.save(network.state_dict(), '/results/model.pth')
      #torch.save(optimizer.state_dict(), '/results/optimizer.pth')

def val():
  torch.cuda.empty_cache()
  network.eval()
  with torch.no_grad():
    for _,(data, target) in enumerate(val_loader):
      
      output = network(data.cuda())
      output = output.cpu();  
      pred = output.data.argmax(1)
    
      val_loss = criterion(output, target.long()).item()
    
      f1=f1_score(target.long().numpy(),pred.numpy(),average="macro")
      correct = pred.eq(target.long().data.view_as(pred)).sum()
      torch.cuda.empty_cache()

  
  print('\nVal set: Avg. loss: {:.4f},f1: {:.4f}, Accuracy: {:.2f}\n'.format(
    val_loss, f1,
    100. * correct / len(val_loader.dataset)))
  

  scheduler.step(np.around(val_loss,2))


def test():
  torch.cuda.empty_cache()
  network.eval()
  with torch.no_grad():
    for _,(data, target) in enumerate(test_loader):
      
      output = network(data.cuda())
      output = output.cpu(); 
      pred = output.data.argmax(1)
    
      test_loss = criterion(output, target.long()).item()
    
      f1=f1_score(target.long().numpy(),pred.numpy(),average="macro")
      correct = pred.eq(target.long().data.view_as(pred)).sum()
      torch.cuda.empty_cache()

  print('\nTest set: Avg. loss: {:.4f},f1: {:.4f}, Accuracy: {:.2f}'.format(
    test_loss, f1,
    100. * correct / len(test_loader.dataset)))
  print(correct, len(test_loader.dataset))
  return 100. * correct / len(test_loader.dataset),f1

for epoch in range(1, n_epochs+1):
  train(epoch)
  if epoch%1 == 0:
    val()
  if epoch%1 == 0:
    test()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# Train Epoch: 1 [0/34799 (0%)]	Loss: 39.901901 	 Correct: 4.69
# Train Epoch: 1 [1280/34799 (4%)]	Loss: 7.585093 	 Correct: 7.81
# Train Epoch: 1 [2560/34799 (7%)]	Loss: 4.006303 	 Correct: 7.81
# Train Epoch: 1 [3840/34799 (11%)]	Loss: 1.541237 	 Correct: 12.50
# Train Epoch: 1 [5120/34799 (15%)]	Loss: 1.120987 	 Correct: 12.50
# Train Epoch: 1 [6400/34799 (18%)]	Loss: 1.151197 	 Correct: 6.25
# Train Epoch: 1 [7680/34799 (22%)]	Loss: 1.150136 	 Correct: 7.81
# Train Epoch: 1 [8960/34799 (26%)]	Loss: 1.127256 	 Correct: 10.94
# Train Epoch: 1 [10240/34799 (29%)]	Loss: 1.103068 	 Correct: 12.50
# Train Epoch: 1 [11520/34799 (33%)]	Loss: 1.157544 	 Correct: 1.56
# Train Epoch: 1 [12800/34799 (37%)]	Loss: 1.141207 	 Correct: 14.06
# Train Epoch: 1 [14080/34799 (40%)]	Loss: 1.094569 	 Correct: 15.62
# Train Epoch: 1 [15360/34799 (44%)]	Loss: 1.108922 	 Correct: 12.50
# Train Epoch: 1 [16640/34799 (48%)]	Loss: 1.120155 	 Correct: 3.12
# Train Epoch: 1 [17920/34799 (51%)]	Loss: 0.988301 	 Correct: 18.75
# Train Epoch: 1 [19200/34799 (55%)]	Loss: 1.064336 	 Correct: 12.50
# Train Epoch: 1 [20480/34799 (59%)]	Loss: 1.048157 	 Correct: 9.38
# Train Epoch: 1 [21760/34799 (62%)]	Loss: 0.964079 	 Correct: 21.88
# Train Epoch: 1 [23040/34799 (66%)]	Loss: 0.983163 	 Correct: 17.19
# Train Epoch: 1 [24320/34799 (70%)]	Loss: 1.051910 	 Correct: 12.50
# Train Epoch: 1 [25600/34799 (74%)]	Loss: 0.964358 	 Correct: 21.88
# Train Epoch: 1 [26880/34799 (77%)]	Loss: 0.914109 	 Correct: 20.31
# Train Epoch: 1 [28160/34799 (81%)]	Loss: 0.961472 	 Correct: 15.62
# Train Epoch: 1 [29440/34799 (85%)]	Loss: 0.998524 	 Correct: 20.31
# Train Epoch: 1 [30720/34799 (88%)]	Loss: 0.963405 	 Correct: 21.88
# Train Epoch: 1 [32000/34799 (92%)]	Loss: 0.975033 	 Correct: 20.31
# Train Epoch: 1 [33280/34799 (96%)]	Loss: 0.902425 	 Correct: 14.06
# Train Epoch: 1 [34560/34799 (99%)]	Loss: 0.926511 	 Correct: 21.88
#
# Val set: Avg. loss: 3.6303,f1: 0.1132, Accuracy: 22.86
#
#
# Test set: Avg. loss: 3.6154,f1: 0.1325, Accuracy: 27.20
# tensor(3435) 12630
# Train Epoch: 2 [0/34799 (0%)]	Loss: 0.897060 	 Correct: 20.31
# Train Epoch: 2 [1280/34799 (4%)]	Loss: 0.838413 	 Correct: 29.69
# Train Epoch: 2 [2560/34799 (7%)]	Loss: 0.814840 	 Correct: 26.56
# Train Epoch: 2 [3840/34799 (11%)]	Loss: 0.914333 	 Correct: 25.00
# Train Epoch: 2 [5120/34799 (15%)]	Loss: 0.809130 	 Correct: 29.69
# Train Epoch: 2 [6400/34799 (18%)]	Loss: 0.697905 	 Correct: 48.44
# Train Epoch: 2 [7680/34799 (22%)]	Loss: 0.699627 	 Correct: 39.06
# Train Epoch: 2 [8960/34799 (26%)]	Loss: 0.800937 	 Correct: 32.81
# Train Epoch: 2 [10240/34799 (29%)]	Loss: 0.647892 	 Correct: 50.00
# Train Epoch: 2 [11520/34799 (33%)]	Loss: 0.651230 	 Correct: 46.88
# Train Epoch: 2 [12800/34799 (37%)]	Loss: 0.626386 	 Correct: 50.00
# Train Epoch: 2 [14080/34799 (40%)]	Loss: 0.548326 	 Correct: 51.56
# Train Epoch: 2 [15360/34799 (44%)]	Loss: 0.564540 	 Correct: 46.88
# Train Epoch: 2 [16640/34799 (48%)]	Loss: 0.546346 	 Correct: 56.25
# Train Epoch: 2 [17920/34799 (51%)]	Loss: 0.623200 	 Correct: 46.88
# Train Epoch: 2 [19200/34799 (55%)]	Loss: 0.442870 	 Correct: 65.62
# Train Epoch: 2 [20480/34799 (59%)]	Loss: 0.502043 	 Correct: 65.62
# Train Epoch: 2 [21760/34799 (62%)]	Loss: 0.489707 	 Correct: 70.31
# Train Epoch: 2 [23040/34799 (66%)]	Loss: 0.382354 	 Correct: 68.75
# Train Epoch: 2 [24320/34799 (70%)]	Loss: 0.417255 	 Correct: 71.88
# Train Epoch: 2 [25600/34799 (74%)]	Loss: 0.358752 	 Correct: 73.44
# Train Epoch: 2 [26880/34799 (77%)]	Loss: 0.328534 	 Correct: 81.25
# Train Epoch: 2 [28160/34799 (81%)]	Loss: 0.332055 	 Correct: 79.69
# Train Epoch: 2 [29440/34799 (85%)]	Loss: 0.261721 	 Correct: 92.19
# Train Epoch: 2 [30720/34799 (88%)]	Loss: 0.214391 	 Correct: 92.19
# Train Epoch: 2 [32000/34799 (92%)]	Loss: 0.280864 	 Correct: 84.38
# Train Epoch: 2 [33280/34799 (96%)]	Loss: 0.214217 	 Correct: 93.75
# Train Epoch: 2 [34560/34799 (99%)]	Loss: 0.285852 	 Correct: 85.94
#
# Val set: Avg. loss: 3.0804,f1: 0.8127, Accuracy: 87.57
#
#
# Test set: Avg. loss: 3.0909,f1: 0.8032, Accuracy: 86.12
# tensor(10877) 12630
# Train Epoch: 3 [0/34799 (0%)]	Loss: 0.351350 	 Correct: 89.06
# Train Epoch: 3 [1280/34799 (4%)]	Loss: 0.306939 	 Correct: 82.81
# Train Epoch: 3 [2560/34799 (7%)]	Loss: 0.220650 	 Correct: 95.31
# Train Epoch: 3 [3840/34799 (11%)]	Loss: 0.206161 	 Correct: 92.19
# Train Epoch: 3 [5120/34799 (15%)]	Loss: 0.237469 	 Correct: 87.50
# Train Epoch: 3 [6400/34799 (18%)]	Loss: 0.260042 	 Correct: 84.38
# Train Epoch: 3 [7680/34799 (22%)]	Loss: 0.225871 	 Correct: 92.19
# Train Epoch: 3 [8960/34799 (26%)]	Loss: 0.183414 	 Correct: 93.75
# Train Epoch: 3 [10240/34799 (29%)]	Loss: 0.183597 	 Correct: 96.88
# Train Epoch: 3 [11520/34799 (33%)]	Loss: 0.194986 	 Correct: 92.19
# Train Epoch: 3 [12800/34799 (37%)]	Loss: 0.199933 	 Correct: 92.19
# Train Epoch: 3 [14080/34799 (40%)]	Loss: 0.178576 	 Correct: 92.19
# Train Epoch: 3 [15360/34799 (44%)]	Loss: 0.239059 	 Correct: 90.62
# Train Epoch: 3 [16640/34799 (48%)]	Loss: 0.278687 	 Correct: 90.62
# Train Epoch: 3 [17920/34799 (51%)]	Loss: 0.139339 	 Correct: 96.88
# Train Epoch: 3 [19200/34799 (55%)]	Loss: 0.201435 	 Correct: 92.19
# Train Epoch: 3 [20480/34799 (59%)]	Loss: 0.120405 	 Correct: 98.44
# Train Epoch: 3 [21760/34799 (62%)]	Loss: 0.137598 	 Correct: 95.31
# Train Epoch: 3 [23040/34799 (66%)]	Loss: 0.333356 	 Correct: 84.38
# Train Epoch: 3 [24320/34799 (70%)]	Loss: 0.222429 	 Correct: 90.62
# Train Epoch: 3 [25600/34799 (74%)]	Loss: 0.164252 	 Correct: 95.31
# Train Epoch: 3 [26880/34799 (77%)]	Loss: 0.188055 	 Correct: 90.62
# Train Epoch: 3 [28160/34799 (81%)]	Loss: 0.159345 	 Correct: 95.31
# Train Epoch: 3 [29440/34799 (85%)]	Loss: 0.196972 	 Correct: 93.75
# Train Epoch: 3 [30720/34799 (88%)]	Loss: 0.142763 	 Correct: 92.19
# Train Epoch: 3 [32000/34799 (92%)]	Loss: 0.133993 	 Correct: 95.31
# Train Epoch: 3 [33280/34799 (96%)]	Loss: 0.165337 	 Correct: 93.75
# Train Epoch: 3 [34560/34799 (99%)]	Loss: 0.130063 	 Correct: 95.31
#
# Val set: Avg. loss: 2.9525,f1: 0.9126, Accuracy: 95.74
#
#
# Test set: Avg. loss: 2.9737,f1: 0.9064, Accuracy: 94.41
# tensor(11924) 12630
# Train Epoch: 4 [0/34799 (0%)]	Loss: 0.146638 	 Correct: 95.31
# Train Epoch: 4 [1280/34799 (4%)]	Loss: 0.159467 	 Correct: 96.88
# Train Epoch: 4 [2560/34799 (7%)]	Loss: 0.168569 	 Correct: 98.44
# Train Epoch: 4 [3840/34799 (11%)]	Loss: 0.160977 	 Correct: 93.75
# Train Epoch: 4 [5120/34799 (15%)]	Loss: 0.142961 	 Correct: 95.31
# Train Epoch: 4 [6400/34799 (18%)]	Loss: 0.115093 	 Correct: 100.00
# Train Epoch: 4 [7680/34799 (22%)]	Loss: 0.117256 	 Correct: 100.00
# Train Epoch: 4 [8960/34799 (26%)]	Loss: 0.136164 	 Correct: 98.44
# Train Epoch: 4 [10240/34799 (29%)]	Loss: 0.105968 	 Correct: 98.44
# Train Epoch: 4 [11520/34799 (33%)]	Loss: 0.123479 	 Correct: 96.88
# Train Epoch: 4 [12800/34799 (37%)]	Loss: 0.181327 	 Correct: 95.31
# Train Epoch: 4 [14080/34799 (40%)]	Loss: 0.114159 	 Correct: 100.00
# Train Epoch: 4 [15360/34799 (44%)]	Loss: 0.122967 	 Correct: 96.88
# Train Epoch: 4 [16640/34799 (48%)]	Loss: 0.118565 	 Correct: 98.44
# Train Epoch: 4 [17920/34799 (51%)]	Loss: 0.134454 	 Correct: 95.31
# Train Epoch: 4 [19200/34799 (55%)]	Loss: 0.164770 	 Correct: 93.75
# Train Epoch: 4 [20480/34799 (59%)]	Loss: 0.143816 	 Correct: 98.44
# Train Epoch: 4 [21760/34799 (62%)]	Loss: 0.183356 	 Correct: 92.19
# Train Epoch: 4 [23040/34799 (66%)]	Loss: 0.122325 	 Correct: 98.44
# Train Epoch: 4 [24320/34799 (70%)]	Loss: 0.108914 	 Correct: 98.44
# Train Epoch: 4 [25600/34799 (74%)]	Loss: 0.118793 	 Correct: 100.00
# Train Epoch: 4 [26880/34799 (77%)]	Loss: 0.112731 	 Correct: 98.44
# Train Epoch: 4 [28160/34799 (81%)]	Loss: 0.122583 	 Correct: 100.00
# Train Epoch: 4 [29440/34799 (85%)]	Loss: 0.119169 	 Correct: 98.44
# Train Epoch: 4 [30720/34799 (88%)]	Loss: 0.191681 	 Correct: 93.75
# Train Epoch: 4 [32000/34799 (92%)]	Loss: 0.106766 	 Correct: 98.44
# Train Epoch: 4 [33280/34799 (96%)]	Loss: 0.104437 	 Correct: 100.00
# Train Epoch: 4 [34560/34799 (99%)]	Loss: 0.097562 	 Correct: 100.00
#
# Val set: Avg. loss: 2.9308,f1: 0.9613, Accuracy: 97.55
#
#
# Test set: Avg. loss: 2.9427,f1: 0.9417, Accuracy: 96.25
# tensor(12156) 12630
# Train Epoch: 5 [0/34799 (0%)]	Loss: 0.115801 	 Correct: 95.31
# Train Epoch: 5 [1280/34799 (4%)]	Loss: 0.137581 	 Correct: 93.75
# Train Epoch: 5 [2560/34799 (7%)]	Loss: 0.095568 	 Correct: 98.44
# Train Epoch: 5 [3840/34799 (11%)]	Loss: 0.093180 	 Correct: 98.44
# Train Epoch: 5 [5120/34799 (15%)]	Loss: 0.114582 	 Correct: 96.88
# Train Epoch: 5 [6400/34799 (18%)]	Loss: 0.138754 	 Correct: 98.44
# Train Epoch: 5 [7680/34799 (22%)]	Loss: 0.100323 	 Correct: 100.00
# Train Epoch: 5 [8960/34799 (26%)]	Loss: 0.094778 	 Correct: 100.00
# Train Epoch: 5 [10240/34799 (29%)]	Loss: 0.150269 	 Correct: 95.31
# Train Epoch: 5 [11520/34799 (33%)]	Loss: 0.107693 	 Correct: 98.44
# Train Epoch: 5 [12800/34799 (37%)]	Loss: 0.114385 	 Correct: 96.88
# Train Epoch: 5 [14080/34799 (40%)]	Loss: 0.104901 	 Correct: 100.00
# Train Epoch: 5 [15360/34799 (44%)]	Loss: 0.116964 	 Correct: 95.31
# Train Epoch: 5 [16640/34799 (48%)]	Loss: 0.107254 	 Correct: 96.88
# Train Epoch: 5 [17920/34799 (51%)]	Loss: 0.122307 	 Correct: 98.44
# Train Epoch: 5 [19200/34799 (55%)]	Loss: 0.095036 	 Correct: 98.44
# Train Epoch: 5 [20480/34799 (59%)]	Loss: 0.127856 	 Correct: 100.00
# Train Epoch: 5 [21760/34799 (62%)]	Loss: 0.103973 	 Correct: 100.00
# Train Epoch: 5 [23040/34799 (66%)]	Loss: 0.103670 	 Correct: 100.00
# Train Epoch: 5 [24320/34799 (70%)]	Loss: 0.091655 	 Correct: 100.00
# Train Epoch: 5 [25600/34799 (74%)]	Loss: 0.123972 	 Correct: 98.44
# Train Epoch: 5 [26880/34799 (77%)]	Loss: 0.099645 	 Correct: 98.44
# Train Epoch: 5 [28160/34799 (81%)]	Loss: 0.097891 	 Correct: 98.44
# Train Epoch: 5 [29440/34799 (85%)]	Loss: 0.106001 	 Correct: 100.00
# Train Epoch: 5 [30720/34799 (88%)]	Loss: 0.105316 	 Correct: 100.00
# Train Epoch: 5 [32000/34799 (92%)]	Loss: 0.105715 	 Correct: 100.00
# Train Epoch: 5 [33280/34799 (96%)]	Loss: 0.085871 	 Correct: 100.00
# Train Epoch: 5 [34560/34799 (99%)]	Loss: 0.082482 	 Correct: 100.00
#
# Val set: Avg. loss: 2.9372,f1: 0.9422, Accuracy: 96.92
#
#
# Test set: Avg. loss: 2.9549,f1: 0.9274, Accuracy: 95.80
# tensor(12100) 12630
# Train Epoch: 6 [0/34799 (0%)]	Loss: 0.080156 	 Correct: 100.00
# Train Epoch: 6 [1280/34799 (4%)]	Loss: 0.094184 	 Correct: 98.44
# Train Epoch: 6 [2560/34799 (7%)]	Loss: 0.102192 	 Correct: 98.44
# Train Epoch: 6 [3840/34799 (11%)]	Loss: 0.110813 	 Correct: 98.44
# Train Epoch: 6 [5120/34799 (15%)]	Loss: 0.108637 	 Correct: 98.44
# Train Epoch: 6 [6400/34799 (18%)]	Loss: 0.102599 	 Correct: 98.44
# Train Epoch: 6 [7680/34799 (22%)]	Loss: 0.106999 	 Correct: 98.44
# Train Epoch: 6 [8960/34799 (26%)]	Loss: 0.102794 	 Correct: 98.44
# Train Epoch: 6 [10240/34799 (29%)]	Loss: 0.107345 	 Correct: 98.44
# Train Epoch: 6 [11520/34799 (33%)]	Loss: 0.090415 	 Correct: 100.00
# Train Epoch: 6 [12800/34799 (37%)]	Loss: 0.109583 	 Correct: 96.88
# Train Epoch: 6 [14080/34799 (40%)]	Loss: 0.095243 	 Correct: 98.44
# Train Epoch: 6 [15360/34799 (44%)]	Loss: 0.099290 	 Correct: 100.00
# Train Epoch: 6 [16640/34799 (48%)]	Loss: 0.165905 	 Correct: 93.75
# Train Epoch: 6 [17920/34799 (51%)]	Loss: 0.076230 	 Correct: 100.00
# Train Epoch: 6 [19200/34799 (55%)]	Loss: 0.135129 	 Correct: 96.88
# Train Epoch: 6 [20480/34799 (59%)]	Loss: 0.076316 	 Correct: 100.00
# Train Epoch: 6 [21760/34799 (62%)]	Loss: 0.075803 	 Correct: 100.00
# Train Epoch: 6 [23040/34799 (66%)]	Loss: 0.119913 	 Correct: 100.00
# Train Epoch: 6 [24320/34799 (70%)]	Loss: 0.129444 	 Correct: 96.88
# Train Epoch: 6 [25600/34799 (74%)]	Loss: 0.104715 	 Correct: 96.88
# Train Epoch: 6 [26880/34799 (77%)]	Loss: 0.094079 	 Correct: 100.00
# Train Epoch: 6 [28160/34799 (81%)]	Loss: 0.098903 	 Correct: 100.00
# Train Epoch: 6 [29440/34799 (85%)]	Loss: 0.078278 	 Correct: 100.00
# Train Epoch: 6 [30720/34799 (88%)]	Loss: 0.104541 	 Correct: 96.88
# Train Epoch: 6 [32000/34799 (92%)]	Loss: 0.124918 	 Correct: 96.88
# Train Epoch: 6 [33280/34799 (96%)]	Loss: 0.099989 	 Correct: 100.00
# Train Epoch: 6 [34560/34799 (99%)]	Loss: 0.094202 	 Correct: 100.00
#
# Val set: Avg. loss: 2.9417,f1: 0.9643, Accuracy: 97.55
#
#
# Test set: Avg. loss: 2.9609,f1: 0.9401, Accuracy: 96.03
# tensor(12128) 12630
# Train Epoch: 7 [0/34799 (0%)]	Loss: 0.119364 	 Correct: 98.44
# Train Epoch: 7 [1280/34799 (4%)]	Loss: 0.102132 	 Correct: 100.00
# Train Epoch: 7 [2560/34799 (7%)]	Loss: 0.210172 	 Correct: 96.88
# Train Epoch: 7 [3840/34799 (11%)]	Loss: 0.144594 	 Correct: 96.88
# Train Epoch: 7 [5120/34799 (15%)]	Loss: 0.147592 	 Correct: 95.31
# Train Epoch: 7 [6400/34799 (18%)]	Loss: 0.128350 	 Correct: 98.44
# Train Epoch: 7 [7680/34799 (22%)]	Loss: 0.081477 	 Correct: 100.00
# Train Epoch: 7 [8960/34799 (26%)]	Loss: 0.082392 	 Correct: 100.00
# Train Epoch: 7 [10240/34799 (29%)]	Loss: 0.128814 	 Correct: 98.44
# Train Epoch: 7 [11520/34799 (33%)]	Loss: 0.087165 	 Correct: 100.00
# Train Epoch: 7 [12800/34799 (37%)]	Loss: 0.105026 	 Correct: 96.88
# Train Epoch: 7 [14080/34799 (40%)]	Loss: 0.096597 	 Correct: 100.00
# Train Epoch: 7 [15360/34799 (44%)]	Loss: 0.083439 	 Correct: 98.44
# Train Epoch: 7 [16640/34799 (48%)]	Loss: 0.071117 	 Correct: 100.00
# Train Epoch: 7 [17920/34799 (51%)]	Loss: 0.104010 	 Correct: 98.44
# Train Epoch: 7 [19200/34799 (55%)]	Loss: 0.102721 	 Correct: 96.88
# Train Epoch: 7 [20480/34799 (59%)]	Loss: 0.072363 	 Correct: 100.00
# Train Epoch: 7 [21760/34799 (62%)]	Loss: 0.074501 	 Correct: 98.44
# Train Epoch: 7 [23040/34799 (66%)]	Loss: 0.097760 	 Correct: 98.44
# Train Epoch: 7 [24320/34799 (70%)]	Loss: 0.085877 	 Correct: 98.44
# Train Epoch: 7 [25600/34799 (74%)]	Loss: 0.111155 	 Correct: 98.44
# Train Epoch: 7 [26880/34799 (77%)]	Loss: 0.100319 	 Correct: 98.44
# Train Epoch: 7 [28160/34799 (81%)]	Loss: 0.071407 	 Correct: 100.00
# Train Epoch: 7 [29440/34799 (85%)]	Loss: 0.069240 	 Correct: 100.00
# Train Epoch: 7 [30720/34799 (88%)]	Loss: 0.081300 	 Correct: 100.00
# Train Epoch: 7 [32000/34799 (92%)]	Loss: 0.081724 	 Correct: 100.00
# Train Epoch: 7 [33280/34799 (96%)]	Loss: 0.088120 	 Correct: 98.44
# Train Epoch: 7 [34560/34799 (99%)]	Loss: 0.093469 	 Correct: 100.00
#
# Val set: Avg. loss: 2.9380,f1: 0.9740, Accuracy: 98.03
#
# Epoch     7: reducing learning rate of group 0 to 5.0000e-04.
#
# Test set: Avg. loss: 2.9491,f1: 0.9523, Accuracy: 97.22
# tensor(12279) 12630
# Train Epoch: 8 [0/34799 (0%)]	Loss: 0.085643 	 Correct: 98.44
# Train Epoch: 8 [1280/34799 (4%)]	Loss: 0.074282 	 Correct: 100.00
# Train Epoch: 8 [2560/34799 (7%)]	Loss: 0.060210 	 Correct: 100.00
# Train Epoch: 8 [3840/34799 (11%)]	Loss: 0.074479 	 Correct: 100.00
# Train Epoch: 8 [5120/34799 (15%)]	Loss: 0.098761 	 Correct: 98.44
# Train Epoch: 8 [6400/34799 (18%)]	Loss: 0.064499 	 Correct: 100.00
# Train Epoch: 8 [7680/34799 (22%)]	Loss: 0.077913 	 Correct: 98.44
# Train Epoch: 8 [8960/34799 (26%)]	Loss: 0.092806 	 Correct: 98.44
# Train Epoch: 8 [10240/34799 (29%)]	Loss: 0.095085 	 Correct: 100.00
# Train Epoch: 8 [11520/34799 (33%)]	Loss: 0.065151 	 Correct: 100.00
# Train Epoch: 8 [12800/34799 (37%)]	Loss: 0.071447 	 Correct: 100.00
# Train Epoch: 8 [14080/34799 (40%)]	Loss: 0.073586 	 Correct: 98.44
# Train Epoch: 8 [15360/34799 (44%)]	Loss: 0.066861 	 Correct: 100.00
# Train Epoch: 8 [16640/34799 (48%)]	Loss: 0.071602 	 Correct: 100.00
# Train Epoch: 8 [17920/34799 (51%)]	Loss: 0.062206 	 Correct: 100.00
# Train Epoch: 8 [19200/34799 (55%)]	Loss: 0.077875 	 Correct: 98.44
# Train Epoch: 8 [20480/34799 (59%)]	Loss: 0.081192 	 Correct: 98.44
# Train Epoch: 8 [21760/34799 (62%)]	Loss: 0.080763 	 Correct: 98.44
# Train Epoch: 8 [23040/34799 (66%)]	Loss: 0.069792 	 Correct: 100.00
# Train Epoch: 8 [24320/34799 (70%)]	Loss: 0.063427 	 Correct: 98.44
# Train Epoch: 8 [25600/34799 (74%)]	Loss: 0.070481 	 Correct: 100.00
# Train Epoch: 8 [26880/34799 (77%)]	Loss: 0.071570 	 Correct: 100.00
# Train Epoch: 8 [28160/34799 (81%)]	Loss: 0.080169 	 Correct: 98.44
# Train Epoch: 8 [29440/34799 (85%)]	Loss: 0.084154 	 Correct: 98.44
# Train Epoch: 8 [30720/34799 (88%)]	Loss: 0.058768 	 Correct: 100.00
# Train Epoch: 8 [32000/34799 (92%)]	Loss: 0.063387 	 Correct: 100.00
# Train Epoch: 8 [33280/34799 (96%)]	Loss: 0.077945 	 Correct: 98.44
# Train Epoch: 8 [34560/34799 (99%)]	Loss: 0.068333 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8931,f1: 0.9731, Accuracy: 97.91
#
#
# Test set: Avg. loss: 2.9079,f1: 0.9533, Accuracy: 97.41
# tensor(12303) 12630
# Train Epoch: 9 [0/34799 (0%)]	Loss: 0.097241 	 Correct: 98.44
# Train Epoch: 9 [1280/34799 (4%)]	Loss: 0.071680 	 Correct: 98.44
# Train Epoch: 9 [2560/34799 (7%)]	Loss: 0.069938 	 Correct: 98.44
# Train Epoch: 9 [3840/34799 (11%)]	Loss: 0.111045 	 Correct: 98.44
# Train Epoch: 9 [5120/34799 (15%)]	Loss: 0.074824 	 Correct: 100.00
# Train Epoch: 9 [6400/34799 (18%)]	Loss: 0.069392 	 Correct: 100.00
# Train Epoch: 9 [7680/34799 (22%)]	Loss: 0.052342 	 Correct: 100.00
# Train Epoch: 9 [8960/34799 (26%)]	Loss: 0.082327 	 Correct: 98.44
# Train Epoch: 9 [10240/34799 (29%)]	Loss: 0.066410 	 Correct: 100.00
# Train Epoch: 9 [11520/34799 (33%)]	Loss: 0.064298 	 Correct: 100.00
# Train Epoch: 9 [12800/34799 (37%)]	Loss: 0.057876 	 Correct: 100.00
# Train Epoch: 9 [14080/34799 (40%)]	Loss: 0.061983 	 Correct: 100.00
# Train Epoch: 9 [15360/34799 (44%)]	Loss: 0.061724 	 Correct: 100.00
# Train Epoch: 9 [16640/34799 (48%)]	Loss: 0.061038 	 Correct: 100.00
# Train Epoch: 9 [17920/34799 (51%)]	Loss: 0.060313 	 Correct: 100.00
# Train Epoch: 9 [19200/34799 (55%)]	Loss: 0.075142 	 Correct: 98.44
# Train Epoch: 9 [20480/34799 (59%)]	Loss: 0.061259 	 Correct: 100.00
# Train Epoch: 9 [21760/34799 (62%)]	Loss: 0.067094 	 Correct: 100.00
# Train Epoch: 9 [23040/34799 (66%)]	Loss: 0.053538 	 Correct: 100.00
# Train Epoch: 9 [24320/34799 (70%)]	Loss: 0.061137 	 Correct: 100.00
# Train Epoch: 9 [25600/34799 (74%)]	Loss: 0.064827 	 Correct: 100.00
# Train Epoch: 9 [26880/34799 (77%)]	Loss: 0.061533 	 Correct: 100.00
# Train Epoch: 9 [28160/34799 (81%)]	Loss: 0.085854 	 Correct: 98.44
# Train Epoch: 9 [29440/34799 (85%)]	Loss: 0.056502 	 Correct: 100.00
# Train Epoch: 9 [30720/34799 (88%)]	Loss: 0.068454 	 Correct: 100.00
# Train Epoch: 9 [32000/34799 (92%)]	Loss: 0.072430 	 Correct: 100.00
# Train Epoch: 9 [33280/34799 (96%)]	Loss: 0.066012 	 Correct: 100.00
# Train Epoch: 9 [34560/34799 (99%)]	Loss: 0.075938 	 Correct: 100.00
#
# Val set: Avg. loss: 2.9080,f1: 0.9769, Accuracy: 98.32
#
#
# Test set: Avg. loss: 2.9197,f1: 0.9604, Accuracy: 97.69
# tensor(12338) 12630
# Train Epoch: 10 [0/34799 (0%)]	Loss: 0.067139 	 Correct: 100.00
# Train Epoch: 10 [1280/34799 (4%)]	Loss: 0.064949 	 Correct: 100.00
# Train Epoch: 10 [2560/34799 (7%)]	Loss: 0.064866 	 Correct: 100.00
# Train Epoch: 10 [3840/34799 (11%)]	Loss: 0.096726 	 Correct: 98.44
# Train Epoch: 10 [5120/34799 (15%)]	Loss: 0.067382 	 Correct: 100.00
# Train Epoch: 10 [6400/34799 (18%)]	Loss: 0.059009 	 Correct: 100.00
# Train Epoch: 10 [7680/34799 (22%)]	Loss: 0.069981 	 Correct: 100.00
# Train Epoch: 10 [8960/34799 (26%)]	Loss: 0.065755 	 Correct: 98.44
# Train Epoch: 10 [10240/34799 (29%)]	Loss: 0.073570 	 Correct: 98.44
# Train Epoch: 10 [11520/34799 (33%)]	Loss: 0.060359 	 Correct: 100.00
# Train Epoch: 10 [12800/34799 (37%)]	Loss: 0.063574 	 Correct: 98.44
# Train Epoch: 10 [14080/34799 (40%)]	Loss: 0.059925 	 Correct: 100.00
# Train Epoch: 10 [15360/34799 (44%)]	Loss: 0.062334 	 Correct: 100.00
# Train Epoch: 10 [16640/34799 (48%)]	Loss: 0.054572 	 Correct: 100.00
# Train Epoch: 10 [17920/34799 (51%)]	Loss: 0.052552 	 Correct: 100.00
# Train Epoch: 10 [19200/34799 (55%)]	Loss: 0.078447 	 Correct: 100.00
# Train Epoch: 10 [20480/34799 (59%)]	Loss: 0.072931 	 Correct: 100.00
# Train Epoch: 10 [21760/34799 (62%)]	Loss: 0.059229 	 Correct: 100.00
# Train Epoch: 10 [23040/34799 (66%)]	Loss: 0.052465 	 Correct: 100.00
# Train Epoch: 10 [24320/34799 (70%)]	Loss: 0.056920 	 Correct: 100.00
# Train Epoch: 10 [25600/34799 (74%)]	Loss: 0.079782 	 Correct: 100.00
# Train Epoch: 10 [26880/34799 (77%)]	Loss: 0.070966 	 Correct: 98.44
# Train Epoch: 10 [28160/34799 (81%)]	Loss: 0.062690 	 Correct: 100.00
# Train Epoch: 10 [29440/34799 (85%)]	Loss: 0.056966 	 Correct: 100.00
# Train Epoch: 10 [30720/34799 (88%)]	Loss: 0.062905 	 Correct: 100.00
# Train Epoch: 10 [32000/34799 (92%)]	Loss: 0.071019 	 Correct: 100.00
# Train Epoch: 10 [33280/34799 (96%)]	Loss: 0.065218 	 Correct: 98.44
# Train Epoch: 10 [34560/34799 (99%)]	Loss: 0.108800 	 Correct: 100.00
#
# Val set: Avg. loss: 2.9277,f1: 0.9772, Accuracy: 98.34
#
#
# Test set: Avg. loss: 2.9354,f1: 0.9611, Accuracy: 97.74
# tensor(12345) 12630
# Train Epoch: 11 [0/34799 (0%)]	Loss: 0.079583 	 Correct: 98.44
# Train Epoch: 11 [1280/34799 (4%)]	Loss: 0.069910 	 Correct: 100.00
# Train Epoch: 11 [2560/34799 (7%)]	Loss: 0.078262 	 Correct: 98.44
# Train Epoch: 11 [3840/34799 (11%)]	Loss: 0.066303 	 Correct: 100.00
# Train Epoch: 11 [5120/34799 (15%)]	Loss: 0.067020 	 Correct: 100.00
# Train Epoch: 11 [6400/34799 (18%)]	Loss: 0.069629 	 Correct: 100.00
# Train Epoch: 11 [7680/34799 (22%)]	Loss: 0.066444 	 Correct: 100.00
# Train Epoch: 11 [8960/34799 (26%)]	Loss: 0.078896 	 Correct: 100.00
# Train Epoch: 11 [10240/34799 (29%)]	Loss: 0.072563 	 Correct: 100.00
# Train Epoch: 11 [11520/34799 (33%)]	Loss: 0.063036 	 Correct: 100.00
# Train Epoch: 11 [12800/34799 (37%)]	Loss: 0.062243 	 Correct: 100.00
# Train Epoch: 11 [14080/34799 (40%)]	Loss: 0.062880 	 Correct: 100.00
# Train Epoch: 11 [15360/34799 (44%)]	Loss: 0.055818 	 Correct: 100.00
# Train Epoch: 11 [16640/34799 (48%)]	Loss: 0.057889 	 Correct: 100.00
# Train Epoch: 11 [17920/34799 (51%)]	Loss: 0.071465 	 Correct: 100.00
# Train Epoch: 11 [19200/34799 (55%)]	Loss: 0.062298 	 Correct: 100.00
# Train Epoch: 11 [20480/34799 (59%)]	Loss: 0.085967 	 Correct: 98.44
# Train Epoch: 11 [21760/34799 (62%)]	Loss: 0.067025 	 Correct: 98.44
# Train Epoch: 11 [23040/34799 (66%)]	Loss: 0.059375 	 Correct: 100.00
# Train Epoch: 11 [24320/34799 (70%)]	Loss: 0.058774 	 Correct: 100.00
# Train Epoch: 11 [25600/34799 (74%)]	Loss: 0.059941 	 Correct: 100.00
# Train Epoch: 11 [26880/34799 (77%)]	Loss: 0.059801 	 Correct: 100.00
# Train Epoch: 11 [28160/34799 (81%)]	Loss: 0.064561 	 Correct: 98.44
# Train Epoch: 11 [29440/34799 (85%)]	Loss: 0.079884 	 Correct: 100.00
# Train Epoch: 11 [30720/34799 (88%)]	Loss: 0.068267 	 Correct: 100.00
# Train Epoch: 11 [32000/34799 (92%)]	Loss: 0.078918 	 Correct: 98.44
# Train Epoch: 11 [33280/34799 (96%)]	Loss: 0.058729 	 Correct: 100.00
# Train Epoch: 11 [34560/34799 (99%)]	Loss: 0.060641 	 Correct: 98.44
#
# Val set: Avg. loss: 2.9008,f1: 0.9839, Accuracy: 98.87
#
# Epoch    11: reducing learning rate of group 0 to 2.5000e-04.
#
# Test set: Avg. loss: 2.9118,f1: 0.9689, Accuracy: 98.22
# tensor(12405) 12630
# Train Epoch: 12 [0/34799 (0%)]	Loss: 0.065462 	 Correct: 100.00
# Train Epoch: 12 [1280/34799 (4%)]	Loss: 0.050331 	 Correct: 100.00
# Train Epoch: 12 [2560/34799 (7%)]	Loss: 0.053632 	 Correct: 100.00
# Train Epoch: 12 [3840/34799 (11%)]	Loss: 0.052186 	 Correct: 100.00
# Train Epoch: 12 [5120/34799 (15%)]	Loss: 0.049391 	 Correct: 100.00
# Train Epoch: 12 [6400/34799 (18%)]	Loss: 0.046510 	 Correct: 100.00
# Train Epoch: 12 [7680/34799 (22%)]	Loss: 0.048241 	 Correct: 100.00
# Train Epoch: 12 [8960/34799 (26%)]	Loss: 0.060591 	 Correct: 98.44
# Train Epoch: 12 [10240/34799 (29%)]	Loss: 0.048706 	 Correct: 100.00
# Train Epoch: 12 [11520/34799 (33%)]	Loss: 0.054717 	 Correct: 98.44
# Train Epoch: 12 [12800/34799 (37%)]	Loss: 0.046137 	 Correct: 100.00
# Train Epoch: 12 [14080/34799 (40%)]	Loss: 0.059545 	 Correct: 100.00
# Train Epoch: 12 [15360/34799 (44%)]	Loss: 0.046133 	 Correct: 100.00
# Train Epoch: 12 [16640/34799 (48%)]	Loss: 0.056599 	 Correct: 100.00
# Train Epoch: 12 [17920/34799 (51%)]	Loss: 0.053792 	 Correct: 100.00
# Train Epoch: 12 [19200/34799 (55%)]	Loss: 0.053952 	 Correct: 98.44
# Train Epoch: 12 [20480/34799 (59%)]	Loss: 0.067644 	 Correct: 100.00
# Train Epoch: 12 [21760/34799 (62%)]	Loss: 0.052257 	 Correct: 100.00
# Train Epoch: 12 [23040/34799 (66%)]	Loss: 0.058027 	 Correct: 100.00
# Train Epoch: 12 [24320/34799 (70%)]	Loss: 0.057520 	 Correct: 98.44
# Train Epoch: 12 [25600/34799 (74%)]	Loss: 0.055441 	 Correct: 100.00
# Train Epoch: 12 [26880/34799 (77%)]	Loss: 0.045359 	 Correct: 100.00
# Train Epoch: 12 [28160/34799 (81%)]	Loss: 0.081847 	 Correct: 98.44
# Train Epoch: 12 [29440/34799 (85%)]	Loss: 0.063724 	 Correct: 100.00
# Train Epoch: 12 [30720/34799 (88%)]	Loss: 0.058911 	 Correct: 100.00
# Train Epoch: 12 [32000/34799 (92%)]	Loss: 0.048076 	 Correct: 100.00
# Train Epoch: 12 [33280/34799 (96%)]	Loss: 0.052487 	 Correct: 100.00
# Train Epoch: 12 [34560/34799 (99%)]	Loss: 0.039727 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8878,f1: 0.9773, Accuracy: 98.44
#
#
# Test set: Avg. loss: 2.9002,f1: 0.9633, Accuracy: 97.93
# tensor(12369) 12630
# Train Epoch: 13 [0/34799 (0%)]	Loss: 0.068261 	 Correct: 98.44
# Train Epoch: 13 [1280/34799 (4%)]	Loss: 0.041745 	 Correct: 100.00
# Train Epoch: 13 [2560/34799 (7%)]	Loss: 0.061555 	 Correct: 100.00
# Train Epoch: 13 [3840/34799 (11%)]	Loss: 0.050298 	 Correct: 100.00
# Train Epoch: 13 [5120/34799 (15%)]	Loss: 0.045202 	 Correct: 100.00
# Train Epoch: 13 [6400/34799 (18%)]	Loss: 0.061848 	 Correct: 100.00
# Train Epoch: 13 [7680/34799 (22%)]	Loss: 0.053712 	 Correct: 100.00
# Train Epoch: 13 [8960/34799 (26%)]	Loss: 0.044542 	 Correct: 100.00
# Train Epoch: 13 [10240/34799 (29%)]	Loss: 0.054756 	 Correct: 100.00
# Train Epoch: 13 [11520/34799 (33%)]	Loss: 0.053944 	 Correct: 100.00
# Train Epoch: 13 [12800/34799 (37%)]	Loss: 0.045080 	 Correct: 100.00
# Train Epoch: 13 [14080/34799 (40%)]	Loss: 0.051338 	 Correct: 100.00
# Train Epoch: 13 [15360/34799 (44%)]	Loss: 0.055905 	 Correct: 100.00
# Train Epoch: 13 [16640/34799 (48%)]	Loss: 0.047294 	 Correct: 100.00
# Train Epoch: 13 [17920/34799 (51%)]	Loss: 0.065684 	 Correct: 98.44
# Train Epoch: 13 [19200/34799 (55%)]	Loss: 0.044543 	 Correct: 100.00
# Train Epoch: 13 [20480/34799 (59%)]	Loss: 0.050614 	 Correct: 100.00
# Train Epoch: 13 [21760/34799 (62%)]	Loss: 0.047081 	 Correct: 100.00
# Train Epoch: 13 [23040/34799 (66%)]	Loss: 0.054295 	 Correct: 100.00
# Train Epoch: 13 [24320/34799 (70%)]	Loss: 0.055927 	 Correct: 100.00
# Train Epoch: 13 [25600/34799 (74%)]	Loss: 0.044655 	 Correct: 100.00
# Train Epoch: 13 [26880/34799 (77%)]	Loss: 0.048341 	 Correct: 100.00
# Train Epoch: 13 [28160/34799 (81%)]	Loss: 0.046454 	 Correct: 100.00
# Train Epoch: 13 [29440/34799 (85%)]	Loss: 0.050923 	 Correct: 100.00
# Train Epoch: 13 [30720/34799 (88%)]	Loss: 0.064973 	 Correct: 98.44
# Train Epoch: 13 [32000/34799 (92%)]	Loss: 0.056527 	 Correct: 100.00
# Train Epoch: 13 [33280/34799 (96%)]	Loss: 0.080662 	 Correct: 98.44
# Train Epoch: 13 [34560/34799 (99%)]	Loss: 0.051130 	 Correct: 98.44
#
# Val set: Avg. loss: 2.8974,f1: 0.9735, Accuracy: 98.25
#
#
# Test set: Avg. loss: 2.9063,f1: 0.9638, Accuracy: 98.06
# tensor(12385) 12630
# Train Epoch: 14 [0/34799 (0%)]	Loss: 0.059585 	 Correct: 98.44
# Train Epoch: 14 [1280/34799 (4%)]	Loss: 0.051758 	 Correct: 100.00
# Train Epoch: 14 [2560/34799 (7%)]	Loss: 0.043003 	 Correct: 100.00
# Train Epoch: 14 [3840/34799 (11%)]	Loss: 0.046519 	 Correct: 100.00
# Train Epoch: 14 [5120/34799 (15%)]	Loss: 0.060538 	 Correct: 100.00
# Train Epoch: 14 [6400/34799 (18%)]	Loss: 0.045409 	 Correct: 100.00
# Train Epoch: 14 [7680/34799 (22%)]	Loss: 0.049257 	 Correct: 100.00
# Train Epoch: 14 [8960/34799 (26%)]	Loss: 0.053033 	 Correct: 98.44
# Train Epoch: 14 [10240/34799 (29%)]	Loss: 0.056761 	 Correct: 100.00
# Train Epoch: 14 [11520/34799 (33%)]	Loss: 0.048900 	 Correct: 100.00
# Train Epoch: 14 [12800/34799 (37%)]	Loss: 0.052999 	 Correct: 100.00
# Train Epoch: 14 [14080/34799 (40%)]	Loss: 0.055561 	 Correct: 100.00
# Train Epoch: 14 [15360/34799 (44%)]	Loss: 0.054064 	 Correct: 100.00
# Train Epoch: 14 [16640/34799 (48%)]	Loss: 0.045825 	 Correct: 100.00
# Train Epoch: 14 [17920/34799 (51%)]	Loss: 0.068675 	 Correct: 96.88
# Train Epoch: 14 [19200/34799 (55%)]	Loss: 0.049582 	 Correct: 100.00
# Train Epoch: 14 [20480/34799 (59%)]	Loss: 0.049135 	 Correct: 100.00
# Train Epoch: 14 [21760/34799 (62%)]	Loss: 0.046610 	 Correct: 100.00
# Train Epoch: 14 [23040/34799 (66%)]	Loss: 0.055025 	 Correct: 100.00
# Train Epoch: 14 [24320/34799 (70%)]	Loss: 0.037757 	 Correct: 100.00
# Train Epoch: 14 [25600/34799 (74%)]	Loss: 0.055460 	 Correct: 100.00
# Train Epoch: 14 [26880/34799 (77%)]	Loss: 0.048693 	 Correct: 100.00
# Train Epoch: 14 [28160/34799 (81%)]	Loss: 0.044017 	 Correct: 100.00
# Train Epoch: 14 [29440/34799 (85%)]	Loss: 0.047175 	 Correct: 100.00
# Train Epoch: 14 [30720/34799 (88%)]	Loss: 0.046132 	 Correct: 100.00
# Train Epoch: 14 [32000/34799 (92%)]	Loss: 0.064069 	 Correct: 100.00
# Train Epoch: 14 [33280/34799 (96%)]	Loss: 0.039651 	 Correct: 100.00
# Train Epoch: 14 [34560/34799 (99%)]	Loss: 0.058982 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8890,f1: 0.9796, Accuracy: 98.62
#
# Epoch    14: reducing learning rate of group 0 to 1.2500e-04.
#
# Test set: Avg. loss: 2.9021,f1: 0.9630, Accuracy: 98.02
# tensor(12380) 12630
# Train Epoch: 15 [0/34799 (0%)]	Loss: 0.066604 	 Correct: 100.00
# Train Epoch: 15 [1280/34799 (4%)]	Loss: 0.065552 	 Correct: 98.44
# Train Epoch: 15 [2560/34799 (7%)]	Loss: 0.051901 	 Correct: 100.00
# Train Epoch: 15 [3840/34799 (11%)]	Loss: 0.038530 	 Correct: 100.00
# Train Epoch: 15 [5120/34799 (15%)]	Loss: 0.067718 	 Correct: 100.00
# Train Epoch: 15 [6400/34799 (18%)]	Loss: 0.040631 	 Correct: 100.00
# Train Epoch: 15 [7680/34799 (22%)]	Loss: 0.041090 	 Correct: 100.00
# Train Epoch: 15 [8960/34799 (26%)]	Loss: 0.039653 	 Correct: 100.00
# Train Epoch: 15 [10240/34799 (29%)]	Loss: 0.039219 	 Correct: 100.00
# Train Epoch: 15 [11520/34799 (33%)]	Loss: 0.046429 	 Correct: 100.00
# Train Epoch: 15 [12800/34799 (37%)]	Loss: 0.061583 	 Correct: 98.44
# Train Epoch: 15 [14080/34799 (40%)]	Loss: 0.042760 	 Correct: 100.00
# Train Epoch: 15 [15360/34799 (44%)]	Loss: 0.046574 	 Correct: 100.00
# Train Epoch: 15 [16640/34799 (48%)]	Loss: 0.038226 	 Correct: 100.00
# Train Epoch: 15 [17920/34799 (51%)]	Loss: 0.043923 	 Correct: 100.00
# Train Epoch: 15 [19200/34799 (55%)]	Loss: 0.045850 	 Correct: 100.00
# Train Epoch: 15 [20480/34799 (59%)]	Loss: 0.047887 	 Correct: 100.00
# Train Epoch: 15 [21760/34799 (62%)]	Loss: 0.039904 	 Correct: 100.00
# Train Epoch: 15 [23040/34799 (66%)]	Loss: 0.042413 	 Correct: 100.00
# Train Epoch: 15 [24320/34799 (70%)]	Loss: 0.041488 	 Correct: 100.00
# Train Epoch: 15 [25600/34799 (74%)]	Loss: 0.039383 	 Correct: 100.00
# Train Epoch: 15 [26880/34799 (77%)]	Loss: 0.050711 	 Correct: 100.00
# Train Epoch: 15 [28160/34799 (81%)]	Loss: 0.050152 	 Correct: 100.00
# Train Epoch: 15 [29440/34799 (85%)]	Loss: 0.041992 	 Correct: 100.00
# Train Epoch: 15 [30720/34799 (88%)]	Loss: 0.052952 	 Correct: 98.44
# Train Epoch: 15 [32000/34799 (92%)]	Loss: 0.043836 	 Correct: 100.00
# Train Epoch: 15 [33280/34799 (96%)]	Loss: 0.034076 	 Correct: 100.00
# Train Epoch: 15 [34560/34799 (99%)]	Loss: 0.052304 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8838,f1: 0.9849, Accuracy: 98.84
#
#
# Test set: Avg. loss: 2.8968,f1: 0.9614, Accuracy: 97.84
# tensor(12357) 12630
# Train Epoch: 16 [0/34799 (0%)]	Loss: 0.040120 	 Correct: 100.00
# Train Epoch: 16 [1280/34799 (4%)]	Loss: 0.047377 	 Correct: 100.00
# Train Epoch: 16 [2560/34799 (7%)]	Loss: 0.050655 	 Correct: 98.44
# Train Epoch: 16 [3840/34799 (11%)]	Loss: 0.048620 	 Correct: 100.00
# Train Epoch: 16 [5120/34799 (15%)]	Loss: 0.043049 	 Correct: 100.00
# Train Epoch: 16 [6400/34799 (18%)]	Loss: 0.041805 	 Correct: 100.00
# Train Epoch: 16 [7680/34799 (22%)]	Loss: 0.044592 	 Correct: 100.00
# Train Epoch: 16 [8960/34799 (26%)]	Loss: 0.049603 	 Correct: 100.00
# Train Epoch: 16 [10240/34799 (29%)]	Loss: 0.044063 	 Correct: 100.00
# Train Epoch: 16 [11520/34799 (33%)]	Loss: 0.041031 	 Correct: 100.00
# Train Epoch: 16 [12800/34799 (37%)]	Loss: 0.036893 	 Correct: 100.00
# Train Epoch: 16 [14080/34799 (40%)]	Loss: 0.072105 	 Correct: 98.44
# Train Epoch: 16 [15360/34799 (44%)]	Loss: 0.039756 	 Correct: 100.00
# Train Epoch: 16 [16640/34799 (48%)]	Loss: 0.042175 	 Correct: 100.00
# Train Epoch: 16 [17920/34799 (51%)]	Loss: 0.040411 	 Correct: 100.00
# Train Epoch: 16 [19200/34799 (55%)]	Loss: 0.039680 	 Correct: 100.00
# Train Epoch: 16 [20480/34799 (59%)]	Loss: 0.044933 	 Correct: 100.00
# Train Epoch: 16 [21760/34799 (62%)]	Loss: 0.048458 	 Correct: 100.00
# Train Epoch: 16 [23040/34799 (66%)]	Loss: 0.038055 	 Correct: 100.00
# Train Epoch: 16 [24320/34799 (70%)]	Loss: 0.040156 	 Correct: 100.00
# Train Epoch: 16 [25600/34799 (74%)]	Loss: 0.048575 	 Correct: 100.00
# Train Epoch: 16 [26880/34799 (77%)]	Loss: 0.037665 	 Correct: 100.00
# Train Epoch: 16 [28160/34799 (81%)]	Loss: 0.038083 	 Correct: 100.00
# Train Epoch: 16 [29440/34799 (85%)]	Loss: 0.048761 	 Correct: 98.44
# Train Epoch: 16 [30720/34799 (88%)]	Loss: 0.053863 	 Correct: 100.00
# Train Epoch: 16 [32000/34799 (92%)]	Loss: 0.037308 	 Correct: 100.00
# Train Epoch: 16 [33280/34799 (96%)]	Loss: 0.049964 	 Correct: 100.00
# Train Epoch: 16 [34560/34799 (99%)]	Loss: 0.042743 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8703,f1: 0.9786, Accuracy: 98.50
#
#
# Test set: Avg. loss: 2.8844,f1: 0.9713, Accuracy: 98.45
# tensor(12434) 12630
# Train Epoch: 17 [0/34799 (0%)]	Loss: 0.043547 	 Correct: 100.00
# Train Epoch: 17 [1280/34799 (4%)]	Loss: 0.036580 	 Correct: 100.00
# Train Epoch: 17 [2560/34799 (7%)]	Loss: 0.038925 	 Correct: 100.00
# Train Epoch: 17 [3840/34799 (11%)]	Loss: 0.028651 	 Correct: 100.00
# Train Epoch: 17 [5120/34799 (15%)]	Loss: 0.047504 	 Correct: 98.44
# Train Epoch: 17 [6400/34799 (18%)]	Loss: 0.033111 	 Correct: 100.00
# Train Epoch: 17 [7680/34799 (22%)]	Loss: 0.033098 	 Correct: 100.00
# Train Epoch: 17 [8960/34799 (26%)]	Loss: 0.052522 	 Correct: 98.44
# Train Epoch: 17 [10240/34799 (29%)]	Loss: 0.048227 	 Correct: 100.00
# Train Epoch: 17 [11520/34799 (33%)]	Loss: 0.041570 	 Correct: 100.00
# Train Epoch: 17 [12800/34799 (37%)]	Loss: 0.036816 	 Correct: 100.00
# Train Epoch: 17 [14080/34799 (40%)]	Loss: 0.044725 	 Correct: 100.00
# Train Epoch: 17 [15360/34799 (44%)]	Loss: 0.040981 	 Correct: 100.00
# Train Epoch: 17 [16640/34799 (48%)]	Loss: 0.050368 	 Correct: 100.00
# Train Epoch: 17 [17920/34799 (51%)]	Loss: 0.043861 	 Correct: 100.00
# Train Epoch: 17 [19200/34799 (55%)]	Loss: 0.035830 	 Correct: 100.00
# Train Epoch: 17 [20480/34799 (59%)]	Loss: 0.040051 	 Correct: 100.00
# Train Epoch: 17 [21760/34799 (62%)]	Loss: 0.044922 	 Correct: 100.00
# Train Epoch: 17 [23040/34799 (66%)]	Loss: 0.050317 	 Correct: 98.44
# Train Epoch: 17 [24320/34799 (70%)]	Loss: 0.043062 	 Correct: 100.00
# Train Epoch: 17 [25600/34799 (74%)]	Loss: 0.042967 	 Correct: 100.00
# Train Epoch: 17 [26880/34799 (77%)]	Loss: 0.054688 	 Correct: 98.44
# Train Epoch: 17 [28160/34799 (81%)]	Loss: 0.041993 	 Correct: 100.00
# Train Epoch: 17 [29440/34799 (85%)]	Loss: 0.037124 	 Correct: 100.00
# Train Epoch: 17 [30720/34799 (88%)]	Loss: 0.048437 	 Correct: 98.44
# Train Epoch: 17 [32000/34799 (92%)]	Loss: 0.050922 	 Correct: 100.00
# Train Epoch: 17 [33280/34799 (96%)]	Loss: 0.036600 	 Correct: 100.00
# Train Epoch: 17 [34560/34799 (99%)]	Loss: 0.043029 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8882,f1: 0.9789, Accuracy: 98.64
#
#
# Test set: Avg. loss: 2.9005,f1: 0.9670, Accuracy: 98.28
# tensor(12413) 12630
# Train Epoch: 18 [0/34799 (0%)]	Loss: 0.036171 	 Correct: 100.00
# Train Epoch: 18 [1280/34799 (4%)]	Loss: 0.053686 	 Correct: 100.00
# Train Epoch: 18 [2560/34799 (7%)]	Loss: 0.048011 	 Correct: 100.00
# Train Epoch: 18 [3840/34799 (11%)]	Loss: 0.035892 	 Correct: 100.00
# Train Epoch: 18 [5120/34799 (15%)]	Loss: 0.039556 	 Correct: 100.00
# Train Epoch: 18 [6400/34799 (18%)]	Loss: 0.048909 	 Correct: 100.00
# Train Epoch: 18 [7680/34799 (22%)]	Loss: 0.038008 	 Correct: 100.00
# Train Epoch: 18 [8960/34799 (26%)]	Loss: 0.038247 	 Correct: 100.00
# Train Epoch: 18 [10240/34799 (29%)]	Loss: 0.039517 	 Correct: 100.00
# Train Epoch: 18 [11520/34799 (33%)]	Loss: 0.040710 	 Correct: 100.00
# Train Epoch: 18 [12800/34799 (37%)]	Loss: 0.058928 	 Correct: 100.00
# Train Epoch: 18 [14080/34799 (40%)]	Loss: 0.043605 	 Correct: 100.00
# Train Epoch: 18 [15360/34799 (44%)]	Loss: 0.045143 	 Correct: 100.00
# Train Epoch: 18 [16640/34799 (48%)]	Loss: 0.030395 	 Correct: 100.00
# Train Epoch: 18 [17920/34799 (51%)]	Loss: 0.041821 	 Correct: 100.00
# Train Epoch: 18 [19200/34799 (55%)]	Loss: 0.037190 	 Correct: 100.00
# Train Epoch: 18 [20480/34799 (59%)]	Loss: 0.039963 	 Correct: 100.00
# Train Epoch: 18 [21760/34799 (62%)]	Loss: 0.043924 	 Correct: 100.00
# Train Epoch: 18 [23040/34799 (66%)]	Loss: 0.044472 	 Correct: 100.00
# Train Epoch: 18 [24320/34799 (70%)]	Loss: 0.050090 	 Correct: 100.00
# Train Epoch: 18 [25600/34799 (74%)]	Loss: 0.039938 	 Correct: 100.00
# Train Epoch: 18 [26880/34799 (77%)]	Loss: 0.032716 	 Correct: 100.00
# Train Epoch: 18 [28160/34799 (81%)]	Loss: 0.037432 	 Correct: 100.00
# Train Epoch: 18 [29440/34799 (85%)]	Loss: 0.037321 	 Correct: 100.00
# Train Epoch: 18 [30720/34799 (88%)]	Loss: 0.038249 	 Correct: 100.00
# Train Epoch: 18 [32000/34799 (92%)]	Loss: 0.035368 	 Correct: 100.00
# Train Epoch: 18 [33280/34799 (96%)]	Loss: 0.039625 	 Correct: 100.00
# Train Epoch: 18 [34560/34799 (99%)]	Loss: 0.039784 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8778,f1: 0.9796, Accuracy: 98.53
#
#
# Test set: Avg. loss: 2.8899,f1: 0.9729, Accuracy: 98.47
# tensor(12437) 12630
# Train Epoch: 19 [0/34799 (0%)]	Loss: 0.033180 	 Correct: 100.00
# Train Epoch: 19 [1280/34799 (4%)]	Loss: 0.038518 	 Correct: 100.00
# Train Epoch: 19 [2560/34799 (7%)]	Loss: 0.071339 	 Correct: 98.44
# Train Epoch: 19 [3840/34799 (11%)]	Loss: 0.031326 	 Correct: 100.00
# Train Epoch: 19 [5120/34799 (15%)]	Loss: 0.049905 	 Correct: 100.00
# Train Epoch: 19 [6400/34799 (18%)]	Loss: 0.037781 	 Correct: 100.00
# Train Epoch: 19 [7680/34799 (22%)]	Loss: 0.035023 	 Correct: 100.00
# Train Epoch: 19 [8960/34799 (26%)]	Loss: 0.041407 	 Correct: 100.00
# Train Epoch: 19 [10240/34799 (29%)]	Loss: 0.043774 	 Correct: 100.00
# Train Epoch: 19 [11520/34799 (33%)]	Loss: 0.050414 	 Correct: 100.00
# Train Epoch: 19 [12800/34799 (37%)]	Loss: 0.035158 	 Correct: 100.00
# Train Epoch: 19 [14080/34799 (40%)]	Loss: 0.046766 	 Correct: 100.00
# Train Epoch: 19 [15360/34799 (44%)]	Loss: 0.046050 	 Correct: 100.00
# Train Epoch: 19 [16640/34799 (48%)]	Loss: 0.036994 	 Correct: 100.00
# Train Epoch: 19 [17920/34799 (51%)]	Loss: 0.039388 	 Correct: 100.00
# Train Epoch: 19 [19200/34799 (55%)]	Loss: 0.056484 	 Correct: 100.00
# Train Epoch: 19 [20480/34799 (59%)]	Loss: 0.049516 	 Correct: 98.44
# Train Epoch: 19 [21760/34799 (62%)]	Loss: 0.045386 	 Correct: 100.00
# Train Epoch: 19 [23040/34799 (66%)]	Loss: 0.037118 	 Correct: 100.00
# Train Epoch: 19 [24320/34799 (70%)]	Loss: 0.041937 	 Correct: 98.44
# Train Epoch: 19 [25600/34799 (74%)]	Loss: 0.034962 	 Correct: 100.00
# Train Epoch: 19 [26880/34799 (77%)]	Loss: 0.040534 	 Correct: 100.00
# Train Epoch: 19 [28160/34799 (81%)]	Loss: 0.042018 	 Correct: 100.00
# Train Epoch: 19 [29440/34799 (85%)]	Loss: 0.040174 	 Correct: 100.00
# Train Epoch: 19 [30720/34799 (88%)]	Loss: 0.043452 	 Correct: 100.00
# Train Epoch: 19 [32000/34799 (92%)]	Loss: 0.038939 	 Correct: 100.00
# Train Epoch: 19 [33280/34799 (96%)]	Loss: 0.040673 	 Correct: 100.00
# Train Epoch: 19 [34560/34799 (99%)]	Loss: 0.033304 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8722,f1: 0.9764, Accuracy: 98.44
#
# Epoch    19: reducing learning rate of group 0 to 6.2500e-05.
#
# Test set: Avg. loss: 2.8854,f1: 0.9675, Accuracy: 98.30
# tensor(12415) 12630
# Train Epoch: 20 [0/34799 (0%)]	Loss: 0.047920 	 Correct: 100.00
# Train Epoch: 20 [1280/34799 (4%)]	Loss: 0.050184 	 Correct: 100.00
# Train Epoch: 20 [2560/34799 (7%)]	Loss: 0.034411 	 Correct: 100.00
# Train Epoch: 20 [3840/34799 (11%)]	Loss: 0.034613 	 Correct: 100.00
# Train Epoch: 20 [5120/34799 (15%)]	Loss: 0.041678 	 Correct: 100.00
# Train Epoch: 20 [6400/34799 (18%)]	Loss: 0.035375 	 Correct: 100.00
# Train Epoch: 20 [7680/34799 (22%)]	Loss: 0.045295 	 Correct: 100.00
# Train Epoch: 20 [8960/34799 (26%)]	Loss: 0.048529 	 Correct: 100.00
# Train Epoch: 20 [10240/34799 (29%)]	Loss: 0.035387 	 Correct: 100.00
# Train Epoch: 20 [11520/34799 (33%)]	Loss: 0.037510 	 Correct: 100.00
# Train Epoch: 20 [12800/34799 (37%)]	Loss: 0.036596 	 Correct: 100.00
# Train Epoch: 20 [14080/34799 (40%)]	Loss: 0.025145 	 Correct: 100.00
# Train Epoch: 20 [15360/34799 (44%)]	Loss: 0.032283 	 Correct: 100.00
# Train Epoch: 20 [16640/34799 (48%)]	Loss: 0.034811 	 Correct: 100.00
# Train Epoch: 20 [17920/34799 (51%)]	Loss: 0.032877 	 Correct: 100.00
# Train Epoch: 20 [19200/34799 (55%)]	Loss: 0.032986 	 Correct: 100.00
# Train Epoch: 20 [20480/34799 (59%)]	Loss: 0.034394 	 Correct: 100.00
# Train Epoch: 20 [21760/34799 (62%)]	Loss: 0.035842 	 Correct: 100.00
# Train Epoch: 20 [23040/34799 (66%)]	Loss: 0.030038 	 Correct: 100.00
# Train Epoch: 20 [24320/34799 (70%)]	Loss: 0.049015 	 Correct: 100.00
# Train Epoch: 20 [25600/34799 (74%)]	Loss: 0.035546 	 Correct: 100.00
# Train Epoch: 20 [26880/34799 (77%)]	Loss: 0.039388 	 Correct: 100.00
# Train Epoch: 20 [28160/34799 (81%)]	Loss: 0.028477 	 Correct: 100.00
# Train Epoch: 20 [29440/34799 (85%)]	Loss: 0.030222 	 Correct: 100.00
# Train Epoch: 20 [30720/34799 (88%)]	Loss: 0.034230 	 Correct: 100.00
# Train Epoch: 20 [32000/34799 (92%)]	Loss: 0.047491 	 Correct: 100.00
# Train Epoch: 20 [33280/34799 (96%)]	Loss: 0.031418 	 Correct: 100.00
# Train Epoch: 20 [34560/34799 (99%)]	Loss: 0.030152 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8635,f1: 0.9844, Accuracy: 98.89
#
#
# Test set: Avg. loss: 2.8812,f1: 0.9672, Accuracy: 98.25
# tensor(12409) 12630
# Train Epoch: 21 [0/34799 (0%)]	Loss: 0.038087 	 Correct: 100.00
# Train Epoch: 21 [1280/34799 (4%)]	Loss: 0.030757 	 Correct: 100.00
# Train Epoch: 21 [2560/34799 (7%)]	Loss: 0.031518 	 Correct: 100.00
# Train Epoch: 21 [3840/34799 (11%)]	Loss: 0.034941 	 Correct: 100.00
# Train Epoch: 21 [5120/34799 (15%)]	Loss: 0.030213 	 Correct: 100.00
# Train Epoch: 21 [6400/34799 (18%)]	Loss: 0.027207 	 Correct: 100.00
# Train Epoch: 21 [7680/34799 (22%)]	Loss: 0.028934 	 Correct: 100.00
# Train Epoch: 21 [8960/34799 (26%)]	Loss: 0.029442 	 Correct: 100.00
# Train Epoch: 21 [10240/34799 (29%)]	Loss: 0.031552 	 Correct: 100.00
# Train Epoch: 21 [11520/34799 (33%)]	Loss: 0.037647 	 Correct: 100.00
# Train Epoch: 21 [12800/34799 (37%)]	Loss: 0.037708 	 Correct: 100.00
# Train Epoch: 21 [14080/34799 (40%)]	Loss: 0.027922 	 Correct: 100.00
# Train Epoch: 21 [15360/34799 (44%)]	Loss: 0.030162 	 Correct: 100.00
# Train Epoch: 21 [16640/34799 (48%)]	Loss: 0.033799 	 Correct: 100.00
# Train Epoch: 21 [17920/34799 (51%)]	Loss: 0.029647 	 Correct: 100.00
# Train Epoch: 21 [19200/34799 (55%)]	Loss: 0.053136 	 Correct: 100.00
# Train Epoch: 21 [20480/34799 (59%)]	Loss: 0.032136 	 Correct: 100.00
# Train Epoch: 21 [21760/34799 (62%)]	Loss: 0.029343 	 Correct: 100.00
# Train Epoch: 21 [23040/34799 (66%)]	Loss: 0.037982 	 Correct: 100.00
# Train Epoch: 21 [24320/34799 (70%)]	Loss: 0.029550 	 Correct: 100.00
# Train Epoch: 21 [25600/34799 (74%)]	Loss: 0.035657 	 Correct: 100.00
# Train Epoch: 21 [26880/34799 (77%)]	Loss: 0.033359 	 Correct: 100.00
# Train Epoch: 21 [28160/34799 (81%)]	Loss: 0.027760 	 Correct: 100.00
# Train Epoch: 21 [29440/34799 (85%)]	Loss: 0.044681 	 Correct: 100.00
# Train Epoch: 21 [30720/34799 (88%)]	Loss: 0.039882 	 Correct: 100.00
# Train Epoch: 21 [32000/34799 (92%)]	Loss: 0.026123 	 Correct: 100.00
# Train Epoch: 21 [33280/34799 (96%)]	Loss: 0.030800 	 Correct: 100.00
# Train Epoch: 21 [34560/34799 (99%)]	Loss: 0.034801 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8625,f1: 0.9812, Accuracy: 98.80
#
#
# Test set: Avg. loss: 2.8789,f1: 0.9662, Accuracy: 98.28
# tensor(12413) 12630
# Train Epoch: 22 [0/34799 (0%)]	Loss: 0.032457 	 Correct: 100.00
# Train Epoch: 22 [1280/34799 (4%)]	Loss: 0.038575 	 Correct: 100.00
# Train Epoch: 22 [2560/34799 (7%)]	Loss: 0.037362 	 Correct: 100.00
# Train Epoch: 22 [3840/34799 (11%)]	Loss: 0.033598 	 Correct: 100.00
# Train Epoch: 22 [5120/34799 (15%)]	Loss: 0.032988 	 Correct: 100.00
# Train Epoch: 22 [6400/34799 (18%)]	Loss: 0.043837 	 Correct: 100.00
# Train Epoch: 22 [7680/34799 (22%)]	Loss: 0.034001 	 Correct: 100.00
# Train Epoch: 22 [8960/34799 (26%)]	Loss: 0.027775 	 Correct: 100.00
# Train Epoch: 22 [10240/34799 (29%)]	Loss: 0.036734 	 Correct: 100.00
# Train Epoch: 22 [11520/34799 (33%)]	Loss: 0.030387 	 Correct: 100.00
# Train Epoch: 22 [12800/34799 (37%)]	Loss: 0.036169 	 Correct: 98.44
# Train Epoch: 22 [14080/34799 (40%)]	Loss: 0.046949 	 Correct: 98.44
# Train Epoch: 22 [15360/34799 (44%)]	Loss: 0.036033 	 Correct: 100.00
# Train Epoch: 22 [16640/34799 (48%)]	Loss: 0.027190 	 Correct: 100.00
# Train Epoch: 22 [17920/34799 (51%)]	Loss: 0.045976 	 Correct: 98.44
# Train Epoch: 22 [19200/34799 (55%)]	Loss: 0.038743 	 Correct: 100.00
# Train Epoch: 22 [20480/34799 (59%)]	Loss: 0.039502 	 Correct: 100.00
# Train Epoch: 22 [21760/34799 (62%)]	Loss: 0.027575 	 Correct: 100.00
# Train Epoch: 22 [23040/34799 (66%)]	Loss: 0.041088 	 Correct: 100.00
# Train Epoch: 22 [24320/34799 (70%)]	Loss: 0.034966 	 Correct: 100.00
# Train Epoch: 22 [25600/34799 (74%)]	Loss: 0.038119 	 Correct: 98.44
# Train Epoch: 22 [26880/34799 (77%)]	Loss: 0.031897 	 Correct: 100.00
# Train Epoch: 22 [28160/34799 (81%)]	Loss: 0.032293 	 Correct: 100.00
# Train Epoch: 22 [29440/34799 (85%)]	Loss: 0.032852 	 Correct: 100.00
# Train Epoch: 22 [30720/34799 (88%)]	Loss: 0.032389 	 Correct: 100.00
# Train Epoch: 22 [32000/34799 (92%)]	Loss: 0.039716 	 Correct: 100.00
# Train Epoch: 22 [33280/34799 (96%)]	Loss: 0.031820 	 Correct: 100.00
# Train Epoch: 22 [34560/34799 (99%)]	Loss: 0.035060 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8684,f1: 0.9844, Accuracy: 98.98
#
#
# Test set: Avg. loss: 2.8830,f1: 0.9692, Accuracy: 98.53
# tensor(12444) 12630
# Train Epoch: 23 [0/34799 (0%)]	Loss: 0.023062 	 Correct: 100.00
# Train Epoch: 23 [1280/34799 (4%)]	Loss: 0.026298 	 Correct: 100.00
# Train Epoch: 23 [2560/34799 (7%)]	Loss: 0.028799 	 Correct: 100.00
# Train Epoch: 23 [3840/34799 (11%)]	Loss: 0.035586 	 Correct: 100.00
# Train Epoch: 23 [5120/34799 (15%)]	Loss: 0.035849 	 Correct: 100.00
# Train Epoch: 23 [6400/34799 (18%)]	Loss: 0.030256 	 Correct: 100.00
# Train Epoch: 23 [7680/34799 (22%)]	Loss: 0.054743 	 Correct: 98.44
# Train Epoch: 23 [8960/34799 (26%)]	Loss: 0.025027 	 Correct: 100.00
# Train Epoch: 23 [10240/34799 (29%)]	Loss: 0.036740 	 Correct: 100.00
# Train Epoch: 23 [11520/34799 (33%)]	Loss: 0.042383 	 Correct: 100.00
# Train Epoch: 23 [12800/34799 (37%)]	Loss: 0.031858 	 Correct: 100.00
# Train Epoch: 23 [14080/34799 (40%)]	Loss: 0.027128 	 Correct: 100.00
# Train Epoch: 23 [15360/34799 (44%)]	Loss: 0.031677 	 Correct: 100.00
# Train Epoch: 23 [16640/34799 (48%)]	Loss: 0.026328 	 Correct: 100.00
# Train Epoch: 23 [17920/34799 (51%)]	Loss: 0.031703 	 Correct: 100.00
# Train Epoch: 23 [19200/34799 (55%)]	Loss: 0.027271 	 Correct: 100.00
# Train Epoch: 23 [20480/34799 (59%)]	Loss: 0.029993 	 Correct: 100.00
# Train Epoch: 23 [21760/34799 (62%)]	Loss: 0.040626 	 Correct: 100.00
# Train Epoch: 23 [23040/34799 (66%)]	Loss: 0.022156 	 Correct: 100.00
# Train Epoch: 23 [24320/34799 (70%)]	Loss: 0.027062 	 Correct: 100.00
# Train Epoch: 23 [25600/34799 (74%)]	Loss: 0.033856 	 Correct: 100.00
# Train Epoch: 23 [26880/34799 (77%)]	Loss: 0.032355 	 Correct: 100.00
# Train Epoch: 23 [28160/34799 (81%)]	Loss: 0.027618 	 Correct: 100.00
# Train Epoch: 23 [29440/34799 (85%)]	Loss: 0.036761 	 Correct: 100.00
# Train Epoch: 23 [30720/34799 (88%)]	Loss: 0.029262 	 Correct: 100.00
# Train Epoch: 23 [32000/34799 (92%)]	Loss: 0.029539 	 Correct: 100.00
# Train Epoch: 23 [33280/34799 (96%)]	Loss: 0.030258 	 Correct: 100.00
# Train Epoch: 23 [34560/34799 (99%)]	Loss: 0.035168 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8615,f1: 0.9818, Accuracy: 98.87
#
# Epoch    23: reducing learning rate of group 0 to 3.1250e-05.
#
# Test set: Avg. loss: 2.8779,f1: 0.9688, Accuracy: 98.46
# tensor(12436) 12630
# Train Epoch: 24 [0/34799 (0%)]	Loss: 0.040999 	 Correct: 100.00
# Train Epoch: 24 [1280/34799 (4%)]	Loss: 0.030716 	 Correct: 100.00
# Train Epoch: 24 [2560/34799 (7%)]	Loss: 0.038126 	 Correct: 100.00
# Train Epoch: 24 [3840/34799 (11%)]	Loss: 0.029939 	 Correct: 100.00
# Train Epoch: 24 [5120/34799 (15%)]	Loss: 0.026920 	 Correct: 100.00
# Train Epoch: 24 [6400/34799 (18%)]	Loss: 0.023996 	 Correct: 100.00
# Train Epoch: 24 [7680/34799 (22%)]	Loss: 0.027532 	 Correct: 100.00
# Train Epoch: 24 [8960/34799 (26%)]	Loss: 0.031301 	 Correct: 100.00
# Train Epoch: 24 [10240/34799 (29%)]	Loss: 0.024964 	 Correct: 100.00
# Train Epoch: 24 [11520/34799 (33%)]	Loss: 0.043885 	 Correct: 100.00
# Train Epoch: 24 [12800/34799 (37%)]	Loss: 0.034989 	 Correct: 100.00
# Train Epoch: 24 [14080/34799 (40%)]	Loss: 0.029102 	 Correct: 100.00
# Train Epoch: 24 [15360/34799 (44%)]	Loss: 0.028416 	 Correct: 100.00
# Train Epoch: 24 [16640/34799 (48%)]	Loss: 0.047098 	 Correct: 100.00
# Train Epoch: 24 [17920/34799 (51%)]	Loss: 0.027090 	 Correct: 100.00
# Train Epoch: 24 [19200/34799 (55%)]	Loss: 0.027994 	 Correct: 100.00
# Train Epoch: 24 [20480/34799 (59%)]	Loss: 0.031571 	 Correct: 100.00
# Train Epoch: 24 [21760/34799 (62%)]	Loss: 0.048518 	 Correct: 100.00
# Train Epoch: 24 [23040/34799 (66%)]	Loss: 0.027189 	 Correct: 100.00
# Train Epoch: 24 [24320/34799 (70%)]	Loss: 0.037972 	 Correct: 100.00
# Train Epoch: 24 [25600/34799 (74%)]	Loss: 0.026572 	 Correct: 100.00
# Train Epoch: 24 [26880/34799 (77%)]	Loss: 0.030495 	 Correct: 100.00
# Train Epoch: 24 [28160/34799 (81%)]	Loss: 0.029358 	 Correct: 100.00
# Train Epoch: 24 [29440/34799 (85%)]	Loss: 0.028891 	 Correct: 100.00
# Train Epoch: 24 [30720/34799 (88%)]	Loss: 0.022261 	 Correct: 100.00
# Train Epoch: 24 [32000/34799 (92%)]	Loss: 0.027471 	 Correct: 100.00
# Train Epoch: 24 [33280/34799 (96%)]	Loss: 0.026808 	 Correct: 100.00
# Train Epoch: 24 [34560/34799 (99%)]	Loss: 0.028703 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8587,f1: 0.9812, Accuracy: 98.80
#
#
# Test set: Avg. loss: 2.8743,f1: 0.9699, Accuracy: 98.53
# tensor(12444) 12630
# Train Epoch: 25 [0/34799 (0%)]	Loss: 0.030221 	 Correct: 100.00
# Train Epoch: 25 [1280/34799 (4%)]	Loss: 0.034398 	 Correct: 100.00
# Train Epoch: 25 [2560/34799 (7%)]	Loss: 0.029964 	 Correct: 100.00
# Train Epoch: 25 [3840/34799 (11%)]	Loss: 0.037428 	 Correct: 100.00
# Train Epoch: 25 [5120/34799 (15%)]	Loss: 0.025873 	 Correct: 100.00
# Train Epoch: 25 [6400/34799 (18%)]	Loss: 0.038546 	 Correct: 100.00
# Train Epoch: 25 [7680/34799 (22%)]	Loss: 0.034794 	 Correct: 100.00
# Train Epoch: 25 [8960/34799 (26%)]	Loss: 0.027035 	 Correct: 100.00
# Train Epoch: 25 [10240/34799 (29%)]	Loss: 0.030544 	 Correct: 100.00
# Train Epoch: 25 [11520/34799 (33%)]	Loss: 0.043964 	 Correct: 100.00
# Train Epoch: 25 [12800/34799 (37%)]	Loss: 0.026878 	 Correct: 100.00
# Train Epoch: 25 [14080/34799 (40%)]	Loss: 0.027754 	 Correct: 100.00
# Train Epoch: 25 [15360/34799 (44%)]	Loss: 0.026538 	 Correct: 100.00
# Train Epoch: 25 [16640/34799 (48%)]	Loss: 0.025390 	 Correct: 100.00
# Train Epoch: 25 [17920/34799 (51%)]	Loss: 0.026694 	 Correct: 100.00
# Train Epoch: 25 [19200/34799 (55%)]	Loss: 0.022800 	 Correct: 100.00
# Train Epoch: 25 [20480/34799 (59%)]	Loss: 0.024102 	 Correct: 100.00
# Train Epoch: 25 [21760/34799 (62%)]	Loss: 0.033305 	 Correct: 100.00
# Train Epoch: 25 [23040/34799 (66%)]	Loss: 0.027998 	 Correct: 100.00
# Train Epoch: 25 [24320/34799 (70%)]	Loss: 0.032326 	 Correct: 100.00
# Train Epoch: 25 [25600/34799 (74%)]	Loss: 0.024533 	 Correct: 100.00
# Train Epoch: 25 [26880/34799 (77%)]	Loss: 0.058047 	 Correct: 98.44
# Train Epoch: 25 [28160/34799 (81%)]	Loss: 0.030938 	 Correct: 100.00
# Train Epoch: 25 [29440/34799 (85%)]	Loss: 0.042181 	 Correct: 100.00
# Train Epoch: 25 [30720/34799 (88%)]	Loss: 0.024307 	 Correct: 100.00
# Train Epoch: 25 [32000/34799 (92%)]	Loss: 0.025344 	 Correct: 100.00
# Train Epoch: 25 [33280/34799 (96%)]	Loss: 0.025420 	 Correct: 100.00
# Train Epoch: 25 [34560/34799 (99%)]	Loss: 0.024796 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8607,f1: 0.9845, Accuracy: 99.02
#
#
# Test set: Avg. loss: 2.8760,f1: 0.9695, Accuracy: 98.44
# tensor(12433) 12630
# Train Epoch: 26 [0/34799 (0%)]	Loss: 0.026046 	 Correct: 100.00
# Train Epoch: 26 [1280/34799 (4%)]	Loss: 0.027617 	 Correct: 100.00
# Train Epoch: 26 [2560/34799 (7%)]	Loss: 0.051227 	 Correct: 100.00
# Train Epoch: 26 [3840/34799 (11%)]	Loss: 0.024260 	 Correct: 100.00
# Train Epoch: 26 [5120/34799 (15%)]	Loss: 0.021565 	 Correct: 100.00
# Train Epoch: 26 [6400/34799 (18%)]	Loss: 0.027918 	 Correct: 100.00
# Train Epoch: 26 [7680/34799 (22%)]	Loss: 0.028060 	 Correct: 100.00
# Train Epoch: 26 [8960/34799 (26%)]	Loss: 0.025519 	 Correct: 100.00
# Train Epoch: 26 [10240/34799 (29%)]	Loss: 0.031266 	 Correct: 100.00
# Train Epoch: 26 [11520/34799 (33%)]	Loss: 0.035158 	 Correct: 100.00
# Train Epoch: 26 [12800/34799 (37%)]	Loss: 0.029083 	 Correct: 100.00
# Train Epoch: 26 [14080/34799 (40%)]	Loss: 0.030644 	 Correct: 100.00
# Train Epoch: 26 [15360/34799 (44%)]	Loss: 0.031074 	 Correct: 100.00
# Train Epoch: 26 [16640/34799 (48%)]	Loss: 0.025339 	 Correct: 100.00
# Train Epoch: 26 [17920/34799 (51%)]	Loss: 0.031521 	 Correct: 100.00
# Train Epoch: 26 [19200/34799 (55%)]	Loss: 0.025440 	 Correct: 100.00
# Train Epoch: 26 [20480/34799 (59%)]	Loss: 0.030253 	 Correct: 100.00
# Train Epoch: 26 [21760/34799 (62%)]	Loss: 0.034382 	 Correct: 100.00
# Train Epoch: 26 [23040/34799 (66%)]	Loss: 0.031454 	 Correct: 100.00
# Train Epoch: 26 [24320/34799 (70%)]	Loss: 0.031579 	 Correct: 100.00
# Train Epoch: 26 [25600/34799 (74%)]	Loss: 0.023332 	 Correct: 100.00
# Train Epoch: 26 [26880/34799 (77%)]	Loss: 0.026479 	 Correct: 100.00
# Train Epoch: 26 [28160/34799 (81%)]	Loss: 0.046859 	 Correct: 100.00
# Train Epoch: 26 [29440/34799 (85%)]	Loss: 0.026210 	 Correct: 100.00
# Train Epoch: 26 [30720/34799 (88%)]	Loss: 0.027682 	 Correct: 100.00
# Train Epoch: 26 [32000/34799 (92%)]	Loss: 0.030392 	 Correct: 100.00
# Train Epoch: 26 [33280/34799 (96%)]	Loss: 0.045276 	 Correct: 100.00
# Train Epoch: 26 [34560/34799 (99%)]	Loss: 0.036187 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8621,f1: 0.9803, Accuracy: 98.66
#
# Epoch    26: reducing learning rate of group 0 to 1.5625e-05.
#
# Test set: Avg. loss: 2.8796,f1: 0.9697, Accuracy: 98.42
# tensor(12431) 12630
# Train Epoch: 27 [0/34799 (0%)]	Loss: 0.040434 	 Correct: 100.00
# Train Epoch: 27 [1280/34799 (4%)]	Loss: 0.043774 	 Correct: 100.00
# Train Epoch: 27 [2560/34799 (7%)]	Loss: 0.028412 	 Correct: 100.00
# Train Epoch: 27 [3840/34799 (11%)]	Loss: 0.031403 	 Correct: 100.00
# Train Epoch: 27 [5120/34799 (15%)]	Loss: 0.030832 	 Correct: 100.00
# Train Epoch: 27 [6400/34799 (18%)]	Loss: 0.021905 	 Correct: 100.00
# Train Epoch: 27 [7680/34799 (22%)]	Loss: 0.037349 	 Correct: 100.00
# Train Epoch: 27 [8960/34799 (26%)]	Loss: 0.026591 	 Correct: 100.00
# Train Epoch: 27 [10240/34799 (29%)]	Loss: 0.019742 	 Correct: 100.00
# Train Epoch: 27 [11520/34799 (33%)]	Loss: 0.029085 	 Correct: 100.00
# Train Epoch: 27 [12800/34799 (37%)]	Loss: 0.032542 	 Correct: 100.00
# Train Epoch: 27 [14080/34799 (40%)]	Loss: 0.026117 	 Correct: 100.00
# Train Epoch: 27 [15360/34799 (44%)]	Loss: 0.032973 	 Correct: 100.00
# Train Epoch: 27 [16640/34799 (48%)]	Loss: 0.027354 	 Correct: 100.00
# Train Epoch: 27 [17920/34799 (51%)]	Loss: 0.028716 	 Correct: 100.00
# Train Epoch: 27 [19200/34799 (55%)]	Loss: 0.038866 	 Correct: 100.00
# Train Epoch: 27 [20480/34799 (59%)]	Loss: 0.028316 	 Correct: 100.00
# Train Epoch: 27 [21760/34799 (62%)]	Loss: 0.035708 	 Correct: 100.00
# Train Epoch: 27 [23040/34799 (66%)]	Loss: 0.024189 	 Correct: 100.00
# Train Epoch: 27 [24320/34799 (70%)]	Loss: 0.028195 	 Correct: 100.00
# Train Epoch: 27 [25600/34799 (74%)]	Loss: 0.023247 	 Correct: 100.00
# Train Epoch: 27 [26880/34799 (77%)]	Loss: 0.026052 	 Correct: 100.00
# Train Epoch: 27 [28160/34799 (81%)]	Loss: 0.027607 	 Correct: 100.00
# Train Epoch: 27 [29440/34799 (85%)]	Loss: 0.024939 	 Correct: 100.00
# Train Epoch: 27 [30720/34799 (88%)]	Loss: 0.029236 	 Correct: 100.00
# Train Epoch: 27 [32000/34799 (92%)]	Loss: 0.037973 	 Correct: 100.00
# Train Epoch: 27 [33280/34799 (96%)]	Loss: 0.022862 	 Correct: 100.00
# Train Epoch: 27 [34560/34799 (99%)]	Loss: 0.039942 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8552,f1: 0.9811, Accuracy: 98.80
#
#
# Test set: Avg. loss: 2.8727,f1: 0.9716, Accuracy: 98.54
# tensor(12446) 12630
# Train Epoch: 28 [0/34799 (0%)]	Loss: 0.028357 	 Correct: 100.00
# Train Epoch: 28 [1280/34799 (4%)]	Loss: 0.028577 	 Correct: 100.00
# Train Epoch: 28 [2560/34799 (7%)]	Loss: 0.036449 	 Correct: 98.44
# Train Epoch: 28 [3840/34799 (11%)]	Loss: 0.026856 	 Correct: 100.00
# Train Epoch: 28 [5120/34799 (15%)]	Loss: 0.027624 	 Correct: 100.00
# Train Epoch: 28 [6400/34799 (18%)]	Loss: 0.033127 	 Correct: 100.00
# Train Epoch: 28 [7680/34799 (22%)]	Loss: 0.025139 	 Correct: 100.00
# Train Epoch: 28 [8960/34799 (26%)]	Loss: 0.031928 	 Correct: 100.00
# Train Epoch: 28 [10240/34799 (29%)]	Loss: 0.024466 	 Correct: 100.00
# Train Epoch: 28 [11520/34799 (33%)]	Loss: 0.025090 	 Correct: 100.00
# Train Epoch: 28 [12800/34799 (37%)]	Loss: 0.027742 	 Correct: 100.00
# Train Epoch: 28 [14080/34799 (40%)]	Loss: 0.022587 	 Correct: 100.00
# Train Epoch: 28 [15360/34799 (44%)]	Loss: 0.033384 	 Correct: 100.00
# Train Epoch: 28 [16640/34799 (48%)]	Loss: 0.024054 	 Correct: 100.00
# Train Epoch: 28 [17920/34799 (51%)]	Loss: 0.030430 	 Correct: 100.00
# Train Epoch: 28 [19200/34799 (55%)]	Loss: 0.042283 	 Correct: 100.00
# Train Epoch: 28 [20480/34799 (59%)]	Loss: 0.032764 	 Correct: 100.00
# Train Epoch: 28 [21760/34799 (62%)]	Loss: 0.034211 	 Correct: 100.00
# Train Epoch: 28 [23040/34799 (66%)]	Loss: 0.032601 	 Correct: 100.00
# Train Epoch: 28 [24320/34799 (70%)]	Loss: 0.025100 	 Correct: 100.00
# Train Epoch: 28 [25600/34799 (74%)]	Loss: 0.034649 	 Correct: 100.00
# Train Epoch: 28 [26880/34799 (77%)]	Loss: 0.042933 	 Correct: 100.00
# Train Epoch: 28 [28160/34799 (81%)]	Loss: 0.027716 	 Correct: 100.00
# Train Epoch: 28 [29440/34799 (85%)]	Loss: 0.028827 	 Correct: 100.00
# Train Epoch: 28 [30720/34799 (88%)]	Loss: 0.027703 	 Correct: 100.00
# Train Epoch: 28 [32000/34799 (92%)]	Loss: 0.030074 	 Correct: 100.00
# Train Epoch: 28 [33280/34799 (96%)]	Loss: 0.032901 	 Correct: 100.00
# Train Epoch: 28 [34560/34799 (99%)]	Loss: 0.028197 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8608,f1: 0.9852, Accuracy: 99.14
#
#
# Test set: Avg. loss: 2.8788,f1: 0.9690, Accuracy: 98.42
# tensor(12430) 12630
# Train Epoch: 29 [0/34799 (0%)]	Loss: 0.038296 	 Correct: 100.00
# Train Epoch: 29 [1280/34799 (4%)]	Loss: 0.021859 	 Correct: 100.00
# Train Epoch: 29 [2560/34799 (7%)]	Loss: 0.030113 	 Correct: 100.00
# Train Epoch: 29 [3840/34799 (11%)]	Loss: 0.026584 	 Correct: 100.00
# Train Epoch: 29 [5120/34799 (15%)]	Loss: 0.023390 	 Correct: 100.00
# Train Epoch: 29 [6400/34799 (18%)]	Loss: 0.026638 	 Correct: 100.00
# Train Epoch: 29 [7680/34799 (22%)]	Loss: 0.026636 	 Correct: 100.00
# Train Epoch: 29 [8960/34799 (26%)]	Loss: 0.024273 	 Correct: 100.00
# Train Epoch: 29 [10240/34799 (29%)]	Loss: 0.026578 	 Correct: 100.00
# Train Epoch: 29 [11520/34799 (33%)]	Loss: 0.029540 	 Correct: 100.00
# Train Epoch: 29 [12800/34799 (37%)]	Loss: 0.022408 	 Correct: 100.00
# Train Epoch: 29 [14080/34799 (40%)]	Loss: 0.025151 	 Correct: 100.00
# Train Epoch: 29 [15360/34799 (44%)]	Loss: 0.021098 	 Correct: 100.00
# Train Epoch: 29 [16640/34799 (48%)]	Loss: 0.043417 	 Correct: 100.00
# Train Epoch: 29 [17920/34799 (51%)]	Loss: 0.031343 	 Correct: 100.00
# Train Epoch: 29 [19200/34799 (55%)]	Loss: 0.030718 	 Correct: 100.00
# Train Epoch: 29 [20480/34799 (59%)]	Loss: 0.018883 	 Correct: 100.00
# Train Epoch: 29 [21760/34799 (62%)]	Loss: 0.032266 	 Correct: 100.00
# Train Epoch: 29 [23040/34799 (66%)]	Loss: 0.027105 	 Correct: 100.00
# Train Epoch: 29 [24320/34799 (70%)]	Loss: 0.027391 	 Correct: 100.00
# Train Epoch: 29 [25600/34799 (74%)]	Loss: 0.033899 	 Correct: 100.00
# Train Epoch: 29 [26880/34799 (77%)]	Loss: 0.025214 	 Correct: 100.00
# Train Epoch: 29 [28160/34799 (81%)]	Loss: 0.028938 	 Correct: 100.00
# Train Epoch: 29 [29440/34799 (85%)]	Loss: 0.033581 	 Correct: 100.00
# Train Epoch: 29 [30720/34799 (88%)]	Loss: 0.020565 	 Correct: 100.00
# Train Epoch: 29 [32000/34799 (92%)]	Loss: 0.023103 	 Correct: 100.00
# Train Epoch: 29 [33280/34799 (96%)]	Loss: 0.035932 	 Correct: 100.00
# Train Epoch: 29 [34560/34799 (99%)]	Loss: 0.028590 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8588,f1: 0.9833, Accuracy: 98.87
#
# Epoch    29: reducing learning rate of group 0 to 7.8125e-06.
#
# Test set: Avg. loss: 2.8768,f1: 0.9713, Accuracy: 98.50
# tensor(12441) 12630
# Train Epoch: 30 [0/34799 (0%)]	Loss: 0.026351 	 Correct: 100.00
# Train Epoch: 30 [1280/34799 (4%)]	Loss: 0.046169 	 Correct: 100.00
# Train Epoch: 30 [2560/34799 (7%)]	Loss: 0.025787 	 Correct: 100.00
# Train Epoch: 30 [3840/34799 (11%)]	Loss: 0.032214 	 Correct: 100.00
# Train Epoch: 30 [5120/34799 (15%)]	Loss: 0.042405 	 Correct: 100.00
# Train Epoch: 30 [6400/34799 (18%)]	Loss: 0.027223 	 Correct: 100.00
# Train Epoch: 30 [7680/34799 (22%)]	Loss: 0.035450 	 Correct: 100.00
# Train Epoch: 30 [8960/34799 (26%)]	Loss: 0.026936 	 Correct: 100.00
# Train Epoch: 30 [10240/34799 (29%)]	Loss: 0.025098 	 Correct: 100.00
# Train Epoch: 30 [11520/34799 (33%)]	Loss: 0.031062 	 Correct: 100.00
# Train Epoch: 30 [12800/34799 (37%)]	Loss: 0.028272 	 Correct: 100.00
# Train Epoch: 30 [14080/34799 (40%)]	Loss: 0.035844 	 Correct: 100.00
# Train Epoch: 30 [15360/34799 (44%)]	Loss: 0.027037 	 Correct: 100.00
# Train Epoch: 30 [16640/34799 (48%)]	Loss: 0.032669 	 Correct: 100.00
# Train Epoch: 30 [17920/34799 (51%)]	Loss: 0.023496 	 Correct: 100.00
# Train Epoch: 30 [19200/34799 (55%)]	Loss: 0.031877 	 Correct: 100.00
# Train Epoch: 30 [20480/34799 (59%)]	Loss: 0.030701 	 Correct: 100.00
# Train Epoch: 30 [21760/34799 (62%)]	Loss: 0.038317 	 Correct: 100.00
# Train Epoch: 30 [23040/34799 (66%)]	Loss: 0.039359 	 Correct: 100.00
# Train Epoch: 30 [24320/34799 (70%)]	Loss: 0.034685 	 Correct: 98.44
# Train Epoch: 30 [25600/34799 (74%)]	Loss: 0.029861 	 Correct: 100.00
# Train Epoch: 30 [26880/34799 (77%)]	Loss: 0.024206 	 Correct: 100.00
# Train Epoch: 30 [28160/34799 (81%)]	Loss: 0.027336 	 Correct: 100.00
# Train Epoch: 30 [29440/34799 (85%)]	Loss: 0.026410 	 Correct: 100.00
# Train Epoch: 30 [30720/34799 (88%)]	Loss: 0.023494 	 Correct: 100.00
# Train Epoch: 30 [32000/34799 (92%)]	Loss: 0.025338 	 Correct: 100.00
# Train Epoch: 30 [33280/34799 (96%)]	Loss: 0.037813 	 Correct: 100.00
# Train Epoch: 30 [34560/34799 (99%)]	Loss: 0.028736 	 Correct: 100.00
#
# Val set: Avg. loss: 2.8563,f1: 0.9846, Accuracy: 99.05
#
#
# Test set: Avg. loss: 2.8767,f1: 0.9699, Accuracy: 98.50
# tensor(12441) 12630

# %% [markdown]
# # **Visualizing STN**

# %%
for i, (data,target) in enumerate(train_loader):
  break
network.eval()
a = data[:,:,:,:].detach()
b = network.stn(data[:,:,:,:].cuda()).cpu().detach()[:,:,:,:]
c = target.long()

def norm (a):
    a = (a-a.min())
    a/=(a.max())
    return a+0.00001


num=5
plt.figure(figsize=(10,2*num))
for i in range(num):
  a[i]=norm(a[i])
  b[i]=norm(b[i])
  plt.subplot(num,2,i*2+1)
  plt.imshow(a[i].permute(1,2,0))
  plt.subplot(num,2,i*2+2)
  plt.imshow(b[i].permute(1,2,0))
plt.tight_layout(pad=0, h_pad=0, w_pad=0)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # **Uncertainty Analysis**
# Epistemic uncertainty: Shows if the model is not trained on this data variety, or if the data or similar is never seen by the model. This uncertainty score is better than blantly guessing anything
# - Low data training
# - Improper training
# - OoD detection
#
# Aleatoric uncertainty: Shows the noise present in the data

# %% [markdown]
# # On full Test Data
# Histogram of confidence estimates for correct, wrong classifications, and also for OoD samples

# %%
kernel_distace_normal,kernel_distace_wrong,kernel_distace_ood = [],[],[]
network.eval()

e=3
with torch.no_grad():
  for _,(data, target) in enumerate(test_loader):
    output = network(data.cuda())
    output = output.cpu()
    pred = output.argmax(1)
  ood = data + e*torch.randn(data.shape)
  new_output = network(ood.cuda())
  new_output = new_output.cpu();
  newpred = new_output.argmax(1)

for i in range (len(target)):
  if target[i] == pred [i]:
    kernel_distace_normal.append(output[i].max(0)[0].item())
  else:
    kernel_distace_wrong.append(output[i].max(0)[0].item())
kernel_distace_ood = new_output.max(1)[0].tolist()

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
n, bins, patches = plt.hist(x=[kernel_distace_normal,kernel_distace_ood], bins='auto', color=['#22FF22','#2222FF'])
plt.xlabel("Confidence"); plt.ylabel("freq"); plt.title("Confidence Histogram")
plt.legend(['Correct','OoD'],loc='upper left')
plt.subplot(1,2,2)
n, bins, patches = plt.hist(x=[kernel_distace_wrong], bins='auto', color=['#FF2222'])
plt.xlabel("Confidence"); plt.ylabel("freq"); plt.title("Confidence Histogram")
plt.legend(['Wrong'],loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Per Class
# Class Estimates for epistemic and aleatoric uncertainties

# %%
network.eval()
with torch.no_grad():
  for _,(data, target) in enumerate(test_loader):
    output = network(data.cuda())
    output = output.cpu(); 
    sigma = network.sigma.cpu()
    target = target.long()

epistemic = np.empty((n_classes, 0)).tolist()
aleatoric = np.empty((n_classes, 0)).tolist()
for i in range (len(target)):
  epistemic[target[i].item()].append(output[i].max(0)[0].item())
  aleatoric[target[i].item()].append(sigma[i].item())
for i in range (n_classes):
  epistemic[i] = np.array(epistemic[i]).mean()
  aleatoric[i] = np.array(aleatoric[i]).mean()


x = np.arange(1,n_classes+1)
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
plt.plot(x, epistemic, label = "Epistemic")
plt.xlabel("class"); plt.ylabel("Average Confidence"); plt.title("Confidence per class");
plt.legend()

plt.subplot(1,2,2) 
plt.plot(x, aleatoric, label = "Aleatoric") 
plt.xlabel("class"); plt.ylabel("Average Noise"); plt.title("Noise per class");
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "

# %% [markdown]
# # Per Sample
# Show uncertainties per Sample

# %%
def norm (a):
    a = (a-a.min())
    a/=(a.max()+0.00000001)
    return a

for i, (data,target) in enumerate(train_loader):
  break


er = [0,0.1,0.2,0.5,2]
plt.figure(figsize=(20,4))
for i in range(len(er)):
  e = er[i]
  sample = data[0] + e*torch.randn(data[0].shape)

  network.eval()
  output = network(sample.view(1,3,32,32).cuda()).cpu().view(-1)
  epistemic, aleatoric = output.max(0)[0].item(), network.sigma[0].item()

  plt.subplot(1,len(er),i+1)
  plt.imshow(norm(sample).permute(1,2,0))
  plt.title("Confidence = {:.3f}, noise = {:.3f}".format(epistemic, aleatoric))


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "

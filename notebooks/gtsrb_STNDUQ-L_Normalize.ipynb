# %% [markdown]
# Import libraries

# %%
from __future__ import print_function
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2
import skimage.morphology as morp
from skimage.filters import rank
from sklearn.utils import shuffle
import csv
from PIL import Image
import torchvision.transforms as transforms
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data_utils
from torchvision import datasets, transforms
from torch.autograd import Variable
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score

# !mkdir data
# !mkdir data/test_images
# !mkdir data/val_images
# !mkdir data/train_images
# %cd data
CUDA_LAUNCH_BLOCKING=1
# Out:
# /content/data

# %% [markdown]
# Get data

# %%
# !wget https://d17h27t6h515a5.cloudfront.net/topher/2017/February/5898cd6f_traffic-signs-data/traffic-signs-data.zip
# !unzip traffic-signs-data.zip
# ! wget https://raw.githubusercontent.com/georgesung/traffic_sign_classification_german/master/signnames.csv
# Out:
# --2021-03-09 07:34:45--  https://d17h27t6h515a5.cloudfront.net/topher/2017/February/5898cd6f_traffic-signs-data/traffic-signs-data.zip
# Resolving d17h27t6h515a5.cloudfront.net (d17h27t6h515a5.cloudfront.net)... 13.224.8.160, 13.224.8.22, 13.224.8.111, ...
# Connecting to d17h27t6h515a5.cloudfront.net (d17h27t6h515a5.cloudfront.net)|13.224.8.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 123524425 (118M) [application/zip]
# Saving to: ‘traffic-signs-data.zip’
#
# traffic-signs-data. 100%[===================>] 117.80M  35.4MB/s    in 3.8s
#
# 2021-03-09 07:34:49 (31.2 MB/s) - ‘traffic-signs-data.zip’ saved [123524425/123524425]
#
# Archive:  traffic-signs-data.zip
#   inflating: test.p
#   inflating: train.p
#   inflating: valid.p

# %% [markdown]
# Transforms

# %%
# data augmentation for training and test time
# Resize all images to 32 * 32 and normalize them to mean = 0 and standard-deviation = 1 based on statistics collected from the training set

data_transforms = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and jitter image brightness
data_jitter_brightness = transforms.Compose([
	  transforms.Resize((32, 32)),
    transforms.ColorJitter(brightness=5),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and jitter image saturation
data_jitter_saturation = transforms.Compose([
	  transforms.Resize((32, 32)),
    transforms.ColorJitter(saturation=5),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and jitter image contrast
data_jitter_contrast = transforms.Compose([
	  transforms.Resize((32, 32)),
    transforms.ColorJitter(contrast=5),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and jitter image hues
data_jitter_hue = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.ColorJitter(hue=0.4),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and rotate image
data_rotate = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and flip image horizontally and vertically
data_hvflip = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(1),
    transforms.RandomVerticalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and flip image horizontally
data_hflip = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and flip image vertically
data_vflip = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomVerticalFlip(1),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and shear image
data_shear = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomAffine(degrees = 15,shear=2),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and translate image
data_translate = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.RandomAffine(degrees = 15,translate=(0.1,0.1)),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and crop image 
data_center = transforms.Compose([
	transforms.Resize((36, 36)),
    transforms.CenterCrop(32),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# Resize, normalize and convert image to grayscale
data_grayscale = transforms.Compose([
	transforms.Resize((32, 32)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629))
])

# %%
training_file = "./train.p"
validation_file= "./valid.p"
testing_file = "./test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)

# signs = []
# with open('signnames.csv', 'r') as csvfile:
#     signnames = csv.reader(csvfile, delimiter=',')
#     next(signnames,None)
#     for row in signnames:
#         signs.append(row[1])
#     csvfile.close()

X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# Number of training examples
n_train = X_train.shape[0]

# Number of testing examples
n_test = X_test.shape[0]

# Number of validation examples.
n_validation = X_valid.shape[0]

# What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# How many unique classes/labels there are in the dataset.
n_classes = len(np.unique(y_train))

print("Number of training examples: ", n_train)
print("Number of testing examples: ", n_test)
print("Number of validation examples: ", n_validation)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples:  34799
# Number of testing examples:  12630
# Number of validation examples:  4410
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# File to images

# %%
for num, image in enumerate(X_train):
    image = np.ascontiguousarray(image)
    img = Image.fromarray(image, 'RGB')
    if not os.path.exists('train_images/{label}'.format(label = str(y_train[num]))):
      os.mkdir('train_images/{label}'.format(label = str(y_train[num])))
    img.save("./train_images/{label}/{i}.jpg".format(i = num, label = str(y_train[num])))

# %%
for num, image in enumerate(X_test):
    image = np.ascontiguousarray(image)
    img = Image.fromarray(image, 'RGB')
    if not os.path.exists('test_images/{label}'.format(label = str(y_test[num]))):
      os.mkdir('test_images/{label}'.format(label = str(y_test[num])))
    img.save("./test_images/{label}/{i}.jpg".format(i = num, label = str(y_test[num])))

# %%
for num, image in enumerate(X_valid):
    image = np.ascontiguousarray(image)
    img = Image.fromarray(image, 'RGB')
    if not os.path.exists('val_images/{label}'.format(label = str(y_valid[num]))):
      os.mkdir('val_images/{label}'.format(label = str(y_valid[num])))
    img.save("./val_images/{label}/{i}.jpg".format(i = num, label = str(y_valid[num])))

# %%
if torch.cuda.is_available():
    use_gpu = True
    print("Using GPU")
else:
	use_gpu = False
	print("Using CPU")
 
FloatTensor = torch.cuda.FloatTensor if use_gpu else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_gpu else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_gpu else torch.ByteTensor
Tensor = FloatTensor
# Out:
# Using GPU

# %% [markdown]
# Dataloaders and dataset

# %%
train_loader = torch.utils.data.DataLoader(
   torch.utils.data.ConcatDataset([datasets.ImageFolder('./train_images', 
   transform=data_transforms)]), batch_size=64, shuffle=True, num_workers=4, pin_memory=use_gpu)

val_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder('./val_images',
                         transform=data_transforms),
    batch_size=4410, shuffle=False, num_workers=4, pin_memory=use_gpu)

test_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder('./test_images',
                         transform=data_transforms),
    batch_size=12630, shuffle=False, num_workers=4, pin_memory=use_gpu)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
nclasses = 43 # GTSRB as 43 classes

# %% [markdown]
# MODEL

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        # CNN layers
        self.conv1 = nn.Conv2d(3, 100, kernel_size=5)
        self.bn1 = nn.BatchNorm2d(100)
        self.conv2 = nn.Conv2d(100, 150, kernel_size=3)
        self.bn2 = nn.BatchNorm2d(150)
        self.conv3 = nn.Conv2d(150, 250, kernel_size=3)
        self.bn3 = nn.BatchNorm2d(250)
        self.conv_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(250*2*2, 350)
        self.fc2 = nn.Linear(350, nclasses)

        self.localization = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
            )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(10 * 4 * 4, 32),
            nn.ReLU(True),
            nn.Linear(32, 3 * 2)
            )
   
        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))


    # Spatial transformer model forward function
    def stn(self, x):
        xs = self.localization(x)
        xs = xs.view(-1, 10 * 4 * 4)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)
        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)
        return x

    def compute_features(self, x):
        # transform the input
        x = self.stn(x)
        self.datain = x
        # Perform forward pass
        x = self.bn1(F.max_pool2d(F.leaky_relu(self.conv1(x)),2))
        x = self.conv_drop(x)
        x = self.bn2(F.max_pool2d(F.leaky_relu(self.conv2(x)),2))
        x = self.conv_drop(x)
        x = self.bn3(F.max_pool2d(F.leaky_relu(self.conv3(x)),2))
        x = self.conv_drop(x)
        x = x.view(-1, 250*2*2)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training, p=0.5)
        return x


class CNN_DUQ(Net):
    def __init__(
        self,
        input_size,
        num_classes,
        centroid_size,
        model_output_size,
        length_scale,
        gamma,
        input_dep_ls=False
    ):
        super().__init__()

        self.gamma = gamma
        self.input_dep_ls=input_dep_ls

        self.W = nn.Parameter(
            torch.zeros(centroid_size, num_classes, model_output_size)
        )
        nn.init.kaiming_normal_(self.W, nonlinearity="relu")


        self.register_buffer("N", torch.zeros(num_classes) + 13)
        self.register_buffer(
            "m", torch.normal(torch.zeros(centroid_size, num_classes), 0.05)
        )
        self.m = self.m * self.N
        
        if input_dep_ls:
            self.sigmann=nn.Linear(model_output_size,1)
        self.sigma = length_scale

    def rbf(self, z):
    
        if self.input_dep_ls:
            self.sigma = torch.sigmoid(self.sigmann(z))+0.01
            
        z = torch.einsum("ij,mnj->imn", z, self.W)

        embeddings = self.m / self.N.unsqueeze(0)

        diff = z - embeddings.unsqueeze(0)
        diff = (diff ** 2).mean(1).div(2 * self.sigma ** 2).mul(-1).exp()

        return diff

    def update_embeddings(self, x, y):
        self.N = self.gamma * self.N + (1 - self.gamma) * y.sum(0)

        z = self.compute_features(x)

        z = torch.einsum("ij,mnj->imn", z, self.W)
        embedding_sum = torch.einsum("ijk,ik->jk", z, y)

        self.m = self.gamma * self.m + (1 - self.gamma) * embedding_sum

    def forward(self, x):
        z = self.compute_features(x)
        y_pred = self.rbf(z)

        return y_pred

length_scale = 2
input_size = 32
num_classes = 43
output_size = 350
embedding_size = 100
learnable_length_scale = False #Learnable length scale
gamma = 0.999
input_dep_ls = True
model = CNN_DUQ(input_size,num_classes,embedding_size,output_size,length_scale,gamma,input_dep_ls).float().cuda()

def calc_gradient_penalty(x, y_pred_sum):
    gradients = torch.autograd.grad(
        outputs=y_pred_sum,
        inputs=x,
        grad_outputs=torch.ones_like(y_pred_sum),
        create_graph=True,
        retain_graph=True,
    )[0]

    gradients = gradients.flatten(start_dim=1)

    # L2 norm
    grad_norm = gradients.norm(2, dim=1)

    # Two sided penalty
    gradient_penalty = ((grad_norm - 1) ** 2).mean()

    return gradient_penalty

# %%
optimizer = optim.Adam(filter(lambda p: p.requires_grad,model.parameters()),lr=0.001,weight_decay=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min',patience=2,factor=0.5,verbose=True)

# %%
def train(epoch,lm):
    
    correct = 0
    training_loss = 0
    
    for batch_idx, (data, target) in enumerate(train_loader):
        model.train()
        data, target = Variable(data), Variable(target)
        if use_gpu:
            data = data.cuda()
            target = target.cuda()
        optimizer.zero_grad()
        output = model(data)
        loss = 10*F.binary_cross_entropy(output, F.one_hot(target.long(),43).float()) + lm*calc_gradient_penalty(model.datain,output.sum(1))
        loss.backward()
        optimizer.step()

        with torch.no_grad():
            model.eval()
            model.update_embeddings(data,F.one_hot(target.long(),43).float())
        max_index = output.max(dim = 1)[1]
        correct += (max_index == target).sum()
        training_loss += loss
        if batch_idx % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss per example: {:.6f}\tLoss: {:.6f}'.format(
                        epoch, batch_idx * len(data), len(train_loader.dataset),
                        100. * batch_idx / len(train_loader), loss.data.item()/(640),loss.data.item()))
    print('\nTraining set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
                training_loss / len(train_loader.dataset), correct, len(train_loader.dataset),
                100. * correct / len(train_loader.dataset)))
def validation():
    model.eval()
    validation_loss = 0
    correct = 0
    for data, target in val_loader:
        with torch.no_grad():
            data, target = Variable(data), Variable(target)
            if use_gpu:
                data = data.cuda()
                target = target.cuda()
            output = model(data)
            validation_loss += F.cross_entropy(output, target, size_average=False).data.item() # sum up batch loss
            pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    validation_loss /= len(val_loader.dataset)
    scheduler.step(np.around(validation_loss,2))
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        validation_loss, correct, len(val_loader.dataset),
        100. * correct / len(val_loader.dataset)))

# %%
lm = 0.1
for epoch in range(1, 11):
    train(epoch,lm)
    validation()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# Train Epoch: 1 [0/34799 (0%)]	Loss per example: 0.048877	Loss: 31.281532
# Train Epoch: 1 [640/34799 (2%)]	Loss per example: 0.008511	Loss: 5.447052
# Train Epoch: 1 [1280/34799 (4%)]	Loss per example: 0.002713	Loss: 1.736096
# Train Epoch: 1 [1920/34799 (6%)]	Loss per example: 0.002254	Loss: 1.442389
# Train Epoch: 1 [2560/34799 (7%)]	Loss per example: 0.002185	Loss: 1.398486
# Train Epoch: 1 [3200/34799 (9%)]	Loss per example: 0.001952	Loss: 1.249493
# Train Epoch: 1 [3840/34799 (11%)]	Loss per example: 0.001935	Loss: 1.238140
# Train Epoch: 1 [4480/34799 (13%)]	Loss per example: 0.002003	Loss: 1.281778
# Train Epoch: 1 [5120/34799 (15%)]	Loss per example: 0.001927	Loss: 1.233404
# Train Epoch: 1 [5760/34799 (17%)]	Loss per example: 0.001757	Loss: 1.124660
# Train Epoch: 1 [6400/34799 (18%)]	Loss per example: 0.001815	Loss: 1.161748
# Train Epoch: 1 [7040/34799 (20%)]	Loss per example: 0.001852	Loss: 1.185093
# Train Epoch: 1 [7680/34799 (22%)]	Loss per example: 0.001844	Loss: 1.180054
# Train Epoch: 1 [8320/34799 (24%)]	Loss per example: 0.001953	Loss: 1.249600
# Train Epoch: 1 [8960/34799 (26%)]	Loss per example: 0.001815	Loss: 1.161397
# Train Epoch: 1 [9600/34799 (28%)]	Loss per example: 0.001702	Loss: 1.089130
# Train Epoch: 1 [10240/34799 (29%)]	Loss per example: 0.001693	Loss: 1.083707
# Train Epoch: 1 [10880/34799 (31%)]	Loss per example: 0.001702	Loss: 1.089354
# Train Epoch: 1 [11520/34799 (33%)]	Loss per example: 0.001705	Loss: 1.091046
# Train Epoch: 1 [12160/34799 (35%)]	Loss per example: 0.001762	Loss: 1.127927
# Train Epoch: 1 [12800/34799 (37%)]	Loss per example: 0.001707	Loss: 1.092367
# Train Epoch: 1 [13440/34799 (39%)]	Loss per example: 0.001700	Loss: 1.088043
# Train Epoch: 1 [14080/34799 (40%)]	Loss per example: 0.001626	Loss: 1.040771
# Train Epoch: 1 [14720/34799 (42%)]	Loss per example: 0.001603	Loss: 1.026068
# Train Epoch: 1 [15360/34799 (44%)]	Loss per example: 0.001658	Loss: 1.061366
# Train Epoch: 1 [16000/34799 (46%)]	Loss per example: 0.001572	Loss: 1.006355
# Train Epoch: 1 [16640/34799 (48%)]	Loss per example: 0.001613	Loss: 1.032471
# Train Epoch: 1 [17280/34799 (50%)]	Loss per example: 0.001485	Loss: 0.950234
# Train Epoch: 1 [17920/34799 (51%)]	Loss per example: 0.001533	Loss: 0.981434
# Train Epoch: 1 [18560/34799 (53%)]	Loss per example: 0.001504	Loss: 0.962638
# Train Epoch: 1 [19200/34799 (55%)]	Loss per example: 0.001499	Loss: 0.959371
# Train Epoch: 1 [19840/34799 (57%)]	Loss per example: 0.001528	Loss: 0.977629
# Train Epoch: 1 [20480/34799 (59%)]	Loss per example: 0.001538	Loss: 0.984217
# Train Epoch: 1 [21120/34799 (61%)]	Loss per example: 0.001514	Loss: 0.968816
# Train Epoch: 1 [21760/34799 (62%)]	Loss per example: 0.001500	Loss: 0.959817
# Train Epoch: 1 [22400/34799 (64%)]	Loss per example: 0.001310	Loss: 0.838225
# Train Epoch: 1 [23040/34799 (66%)]	Loss per example: 0.001531	Loss: 0.979819
# Train Epoch: 1 [23680/34799 (68%)]	Loss per example: 0.001441	Loss: 0.922102
# Train Epoch: 1 [24320/34799 (70%)]	Loss per example: 0.001321	Loss: 0.845530
# Train Epoch: 1 [24960/34799 (72%)]	Loss per example: 0.001246	Loss: 0.797418
# Train Epoch: 1 [25600/34799 (74%)]	Loss per example: 0.001324	Loss: 0.847426
# Train Epoch: 1 [26240/34799 (75%)]	Loss per example: 0.001382	Loss: 0.884798
# Train Epoch: 1 [26880/34799 (77%)]	Loss per example: 0.001175	Loss: 0.752152
# Train Epoch: 1 [27520/34799 (79%)]	Loss per example: 0.001267	Loss: 0.810729
# Train Epoch: 1 [28160/34799 (81%)]	Loss per example: 0.001327	Loss: 0.849231
# Train Epoch: 1 [28800/34799 (83%)]	Loss per example: 0.001232	Loss: 0.788526
# Train Epoch: 1 [29440/34799 (85%)]	Loss per example: 0.001241	Loss: 0.793951
# Train Epoch: 1 [30080/34799 (86%)]	Loss per example: 0.001134	Loss: 0.725798
# Train Epoch: 1 [30720/34799 (88%)]	Loss per example: 0.001199	Loss: 0.767425
# Train Epoch: 1 [31360/34799 (90%)]	Loss per example: 0.001184	Loss: 0.757550
# Train Epoch: 1 [32000/34799 (92%)]	Loss per example: 0.001178	Loss: 0.753799
# Train Epoch: 1 [32640/34799 (94%)]	Loss per example: 0.001149	Loss: 0.735232
# Train Epoch: 1 [33280/34799 (96%)]	Loss per example: 0.001159	Loss: 0.741592
# Train Epoch: 1 [33920/34799 (97%)]	Loss per example: 0.001055	Loss: 0.675164
# Train Epoch: 1 [34560/34799 (99%)]	Loss per example: 0.001110	Loss: 0.710115
#
# Training set: Average loss: 0.0207, Accuracy: 7793/34799 (22%)
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Validation set: Average loss: 3.3437, Accuracy: 2664/4410 (60%)
#
# Train Epoch: 2 [0/34799 (0%)]	Loss per example: 0.001053	Loss: 0.674231
# Train Epoch: 2 [640/34799 (2%)]	Loss per example: 0.000957	Loss: 0.612720
# Train Epoch: 2 [1280/34799 (4%)]	Loss per example: 0.000848	Loss: 0.542792
# Train Epoch: 2 [1920/34799 (6%)]	Loss per example: 0.000881	Loss: 0.563530
# Train Epoch: 2 [2560/34799 (7%)]	Loss per example: 0.000982	Loss: 0.628753
# Train Epoch: 2 [3200/34799 (9%)]	Loss per example: 0.000949	Loss: 0.607194
# Train Epoch: 2 [3840/34799 (11%)]	Loss per example: 0.001089	Loss: 0.696857
# Train Epoch: 2 [4480/34799 (13%)]	Loss per example: 0.000801	Loss: 0.512515
# Train Epoch: 2 [5120/34799 (15%)]	Loss per example: 0.000859	Loss: 0.549890
# Train Epoch: 2 [5760/34799 (17%)]	Loss per example: 0.000855	Loss: 0.546901
# Train Epoch: 2 [6400/34799 (18%)]	Loss per example: 0.000752	Loss: 0.480962
# Train Epoch: 2 [7040/34799 (20%)]	Loss per example: 0.000826	Loss: 0.528324
# Train Epoch: 2 [7680/34799 (22%)]	Loss per example: 0.000652	Loss: 0.417145
# Train Epoch: 2 [8320/34799 (24%)]	Loss per example: 0.000908	Loss: 0.581073
# Train Epoch: 2 [8960/34799 (26%)]	Loss per example: 0.000733	Loss: 0.468889
# Train Epoch: 2 [9600/34799 (28%)]	Loss per example: 0.000799	Loss: 0.511299
# Train Epoch: 2 [10240/34799 (29%)]	Loss per example: 0.000733	Loss: 0.469368
# Train Epoch: 2 [10880/34799 (31%)]	Loss per example: 0.000562	Loss: 0.359837
# Train Epoch: 2 [11520/34799 (33%)]	Loss per example: 0.000621	Loss: 0.397198
# Train Epoch: 2 [12160/34799 (35%)]	Loss per example: 0.000629	Loss: 0.402391
# Train Epoch: 2 [12800/34799 (37%)]	Loss per example: 0.000577	Loss: 0.369285
# Train Epoch: 2 [13440/34799 (39%)]	Loss per example: 0.000582	Loss: 0.372416
# Train Epoch: 2 [14080/34799 (40%)]	Loss per example: 0.000638	Loss: 0.408417
# Train Epoch: 2 [14720/34799 (42%)]	Loss per example: 0.000683	Loss: 0.437160
# Train Epoch: 2 [15360/34799 (44%)]	Loss per example: 0.000544	Loss: 0.348033
# Train Epoch: 2 [16000/34799 (46%)]	Loss per example: 0.000654	Loss: 0.418464
# Train Epoch: 2 [16640/34799 (48%)]	Loss per example: 0.000622	Loss: 0.397889
# Train Epoch: 2 [17280/34799 (50%)]	Loss per example: 0.000573	Loss: 0.366679
# Train Epoch: 2 [17920/34799 (51%)]	Loss per example: 0.000558	Loss: 0.357145
# Train Epoch: 2 [18560/34799 (53%)]	Loss per example: 0.000640	Loss: 0.409572
# Train Epoch: 2 [19200/34799 (55%)]	Loss per example: 0.000469	Loss: 0.299862
# Train Epoch: 2 [19840/34799 (57%)]	Loss per example: 0.000586	Loss: 0.374762
# Train Epoch: 2 [20480/34799 (59%)]	Loss per example: 0.000546	Loss: 0.349160
# Train Epoch: 2 [21120/34799 (61%)]	Loss per example: 0.000437	Loss: 0.279675
# Train Epoch: 2 [21760/34799 (62%)]	Loss per example: 0.000468	Loss: 0.299523
# Train Epoch: 2 [22400/34799 (64%)]	Loss per example: 0.000430	Loss: 0.275188
# Train Epoch: 2 [23040/34799 (66%)]	Loss per example: 0.000489	Loss: 0.313126
# Train Epoch: 2 [23680/34799 (68%)]	Loss per example: 0.000433	Loss: 0.277137
# Train Epoch: 2 [24320/34799 (70%)]	Loss per example: 0.000474	Loss: 0.303204
# Train Epoch: 2 [24960/34799 (72%)]	Loss per example: 0.000421	Loss: 0.269405
# Train Epoch: 2 [25600/34799 (74%)]	Loss per example: 0.000360	Loss: 0.230637
# Train Epoch: 2 [26240/34799 (75%)]	Loss per example: 0.000384	Loss: 0.245443
# Train Epoch: 2 [26880/34799 (77%)]	Loss per example: 0.000492	Loss: 0.315017
# Train Epoch: 2 [27520/34799 (79%)]	Loss per example: 0.000439	Loss: 0.281086
# Train Epoch: 2 [28160/34799 (81%)]	Loss per example: 0.000536	Loss: 0.343280
# Train Epoch: 2 [28800/34799 (83%)]	Loss per example: 0.000406	Loss: 0.259989
# Train Epoch: 2 [29440/34799 (85%)]	Loss per example: 0.000482	Loss: 0.308398
# Train Epoch: 2 [30080/34799 (86%)]	Loss per example: 0.000360	Loss: 0.230330
# Train Epoch: 2 [30720/34799 (88%)]	Loss per example: 0.000407	Loss: 0.260557
# Train Epoch: 2 [31360/34799 (90%)]	Loss per example: 0.000386	Loss: 0.246986
# Train Epoch: 2 [32000/34799 (92%)]	Loss per example: 0.000330	Loss: 0.210920
# Train Epoch: 2 [32640/34799 (94%)]	Loss per example: 0.000393	Loss: 0.251556
# Train Epoch: 2 [33280/34799 (96%)]	Loss per example: 0.000492	Loss: 0.314591
# Train Epoch: 2 [33920/34799 (97%)]	Loss per example: 0.000446	Loss: 0.285629
# Train Epoch: 2 [34560/34799 (99%)]	Loss per example: 0.000474	Loss: 0.303191
#
# Training set: Average loss: 0.0062, Accuracy: 26219/34799 (75%)
#
#
# Validation set: Average loss: 3.0144, Accuracy: 4134/4410 (94%)
#
# Train Epoch: 3 [0/34799 (0%)]	Loss per example: 0.000312	Loss: 0.199456
# Train Epoch: 3 [640/34799 (2%)]	Loss per example: 0.000359	Loss: 0.229648
# Train Epoch: 3 [1280/34799 (4%)]	Loss per example: 0.000312	Loss: 0.199965
# Train Epoch: 3 [1920/34799 (6%)]	Loss per example: 0.000303	Loss: 0.193915
# Train Epoch: 3 [2560/34799 (7%)]	Loss per example: 0.000350	Loss: 0.223688
# Train Epoch: 3 [3200/34799 (9%)]	Loss per example: 0.000348	Loss: 0.222605
# Train Epoch: 3 [3840/34799 (11%)]	Loss per example: 0.000334	Loss: 0.213998
# Train Epoch: 3 [4480/34799 (13%)]	Loss per example: 0.000466	Loss: 0.298477
# Train Epoch: 3 [5120/34799 (15%)]	Loss per example: 0.000334	Loss: 0.213790
# Train Epoch: 3 [5760/34799 (17%)]	Loss per example: 0.000345	Loss: 0.221008
# Train Epoch: 3 [6400/34799 (18%)]	Loss per example: 0.000362	Loss: 0.231930
# Train Epoch: 3 [7040/34799 (20%)]	Loss per example: 0.000267	Loss: 0.170825
# Train Epoch: 3 [7680/34799 (22%)]	Loss per example: 0.000352	Loss: 0.225392
# Train Epoch: 3 [8320/34799 (24%)]	Loss per example: 0.000402	Loss: 0.257280
# Train Epoch: 3 [8960/34799 (26%)]	Loss per example: 0.000324	Loss: 0.207522
# Train Epoch: 3 [9600/34799 (28%)]	Loss per example: 0.000350	Loss: 0.224022
# Train Epoch: 3 [10240/34799 (29%)]	Loss per example: 0.000304	Loss: 0.194429
# Train Epoch: 3 [10880/34799 (31%)]	Loss per example: 0.000348	Loss: 0.222904
# Train Epoch: 3 [11520/34799 (33%)]	Loss per example: 0.000374	Loss: 0.239247
# Train Epoch: 3 [12160/34799 (35%)]	Loss per example: 0.000393	Loss: 0.251314
# Train Epoch: 3 [12800/34799 (37%)]	Loss per example: 0.000304	Loss: 0.194673
# Train Epoch: 3 [13440/34799 (39%)]	Loss per example: 0.000422	Loss: 0.269971
# Train Epoch: 3 [14080/34799 (40%)]	Loss per example: 0.000305	Loss: 0.194921
# Train Epoch: 3 [14720/34799 (42%)]	Loss per example: 0.000409	Loss: 0.261528
# Train Epoch: 3 [15360/34799 (44%)]	Loss per example: 0.000290	Loss: 0.185599
# Train Epoch: 3 [16000/34799 (46%)]	Loss per example: 0.000330	Loss: 0.211192
# Train Epoch: 3 [16640/34799 (48%)]	Loss per example: 0.000275	Loss: 0.176125
# Train Epoch: 3 [17280/34799 (50%)]	Loss per example: 0.000428	Loss: 0.273913
# Train Epoch: 3 [17920/34799 (51%)]	Loss per example: 0.000341	Loss: 0.218338
# Train Epoch: 3 [18560/34799 (53%)]	Loss per example: 0.000275	Loss: 0.175898
# Train Epoch: 3 [19200/34799 (55%)]	Loss per example: 0.000309	Loss: 0.197880
# Train Epoch: 3 [19840/34799 (57%)]	Loss per example: 0.000295	Loss: 0.189036
# Train Epoch: 3 [20480/34799 (59%)]	Loss per example: 0.000245	Loss: 0.156864
# Train Epoch: 3 [21120/34799 (61%)]	Loss per example: 0.000317	Loss: 0.203121
# Train Epoch: 3 [21760/34799 (62%)]	Loss per example: 0.000280	Loss: 0.179231
# Train Epoch: 3 [22400/34799 (64%)]	Loss per example: 0.000331	Loss: 0.211891
# Train Epoch: 3 [23040/34799 (66%)]	Loss per example: 0.000367	Loss: 0.235010
# Train Epoch: 3 [23680/34799 (68%)]	Loss per example: 0.000247	Loss: 0.158080
# Train Epoch: 3 [24320/34799 (70%)]	Loss per example: 0.000309	Loss: 0.197880
# Train Epoch: 3 [24960/34799 (72%)]	Loss per example: 0.000290	Loss: 0.185693
# Train Epoch: 3 [25600/34799 (74%)]	Loss per example: 0.000331	Loss: 0.211671
# Train Epoch: 3 [26240/34799 (75%)]	Loss per example: 0.000228	Loss: 0.145745
# Train Epoch: 3 [26880/34799 (77%)]	Loss per example: 0.000288	Loss: 0.184038
# Train Epoch: 3 [27520/34799 (79%)]	Loss per example: 0.000282	Loss: 0.180628
# Train Epoch: 3 [28160/34799 (81%)]	Loss per example: 0.000305	Loss: 0.195253
# Train Epoch: 3 [28800/34799 (83%)]	Loss per example: 0.000257	Loss: 0.164560
# Train Epoch: 3 [29440/34799 (85%)]	Loss per example: 0.000232	Loss: 0.148508
# Train Epoch: 3 [30080/34799 (86%)]	Loss per example: 0.000375	Loss: 0.239733
# Train Epoch: 3 [30720/34799 (88%)]	Loss per example: 0.000255	Loss: 0.163069
# Train Epoch: 3 [31360/34799 (90%)]	Loss per example: 0.000249	Loss: 0.159496
# Train Epoch: 3 [32000/34799 (92%)]	Loss per example: 0.000361	Loss: 0.231235
# Train Epoch: 3 [32640/34799 (94%)]	Loss per example: 0.000330	Loss: 0.211199
# Train Epoch: 3 [33280/34799 (96%)]	Loss per example: 0.000464	Loss: 0.296699
# Train Epoch: 3 [33920/34799 (97%)]	Loss per example: 0.000356	Loss: 0.227869
# Train Epoch: 3 [34560/34799 (99%)]	Loss per example: 0.000289	Loss: 0.184949
#
# Training set: Average loss: 0.0034, Accuracy: 31989/34799 (92%)
#
#
# Validation set: Average loss: 2.9967, Accuracy: 4166/4410 (94%)
#
# Train Epoch: 4 [0/34799 (0%)]	Loss per example: 0.000281	Loss: 0.180078
# Train Epoch: 4 [640/34799 (2%)]	Loss per example: 0.000414	Loss: 0.264912
# Train Epoch: 4 [1280/34799 (4%)]	Loss per example: 0.000360	Loss: 0.230174
# Train Epoch: 4 [1920/34799 (6%)]	Loss per example: 0.000241	Loss: 0.154555
# Train Epoch: 4 [2560/34799 (7%)]	Loss per example: 0.000314	Loss: 0.201230
# Train Epoch: 4 [3200/34799 (9%)]	Loss per example: 0.000212	Loss: 0.135950
# Train Epoch: 4 [3840/34799 (11%)]	Loss per example: 0.000254	Loss: 0.162788
# Train Epoch: 4 [4480/34799 (13%)]	Loss per example: 0.000312	Loss: 0.199682
# Train Epoch: 4 [5120/34799 (15%)]	Loss per example: 0.000299	Loss: 0.191114
# Train Epoch: 4 [5760/34799 (17%)]	Loss per example: 0.000264	Loss: 0.169275
# Train Epoch: 4 [6400/34799 (18%)]	Loss per example: 0.000277	Loss: 0.177524
# Train Epoch: 4 [7040/34799 (20%)]	Loss per example: 0.000323	Loss: 0.206909
# Train Epoch: 4 [7680/34799 (22%)]	Loss per example: 0.000322	Loss: 0.206305
# Train Epoch: 4 [8320/34799 (24%)]	Loss per example: 0.000272	Loss: 0.174210
# Train Epoch: 4 [8960/34799 (26%)]	Loss per example: 0.000284	Loss: 0.182040
# Train Epoch: 4 [9600/34799 (28%)]	Loss per example: 0.000293	Loss: 0.187444
# Train Epoch: 4 [10240/34799 (29%)]	Loss per example: 0.000284	Loss: 0.181839
# Train Epoch: 4 [10880/34799 (31%)]	Loss per example: 0.000234	Loss: 0.149892
# Train Epoch: 4 [11520/34799 (33%)]	Loss per example: 0.000278	Loss: 0.177955
# Train Epoch: 4 [12160/34799 (35%)]	Loss per example: 0.000279	Loss: 0.178842
# Train Epoch: 4 [12800/34799 (37%)]	Loss per example: 0.000280	Loss: 0.179238
# Train Epoch: 4 [13440/34799 (39%)]	Loss per example: 0.000252	Loss: 0.161268
# Train Epoch: 4 [14080/34799 (40%)]	Loss per example: 0.000270	Loss: 0.172510
# Train Epoch: 4 [14720/34799 (42%)]	Loss per example: 0.000299	Loss: 0.191131
# Train Epoch: 4 [15360/34799 (44%)]	Loss per example: 0.000254	Loss: 0.162816
# Train Epoch: 4 [16000/34799 (46%)]	Loss per example: 0.000279	Loss: 0.178854
# Train Epoch: 4 [16640/34799 (48%)]	Loss per example: 0.000241	Loss: 0.153957
# Train Epoch: 4 [17280/34799 (50%)]	Loss per example: 0.000282	Loss: 0.180699
# Train Epoch: 4 [17920/34799 (51%)]	Loss per example: 0.000327	Loss: 0.209585
# Train Epoch: 4 [18560/34799 (53%)]	Loss per example: 0.000212	Loss: 0.135541
# Train Epoch: 4 [19200/34799 (55%)]	Loss per example: 0.000330	Loss: 0.211439
# Train Epoch: 4 [19840/34799 (57%)]	Loss per example: 0.000219	Loss: 0.139869
# Train Epoch: 4 [20480/34799 (59%)]	Loss per example: 0.000280	Loss: 0.179033
# Train Epoch: 4 [21120/34799 (61%)]	Loss per example: 0.000293	Loss: 0.187807
# Train Epoch: 4 [21760/34799 (62%)]	Loss per example: 0.000222	Loss: 0.142198
# Train Epoch: 4 [22400/34799 (64%)]	Loss per example: 0.000277	Loss: 0.177282
# Train Epoch: 4 [23040/34799 (66%)]	Loss per example: 0.000269	Loss: 0.171987
# Train Epoch: 4 [23680/34799 (68%)]	Loss per example: 0.000177	Loss: 0.113094
# Train Epoch: 4 [24320/34799 (70%)]	Loss per example: 0.000205	Loss: 0.131376
# Train Epoch: 4 [24960/34799 (72%)]	Loss per example: 0.000231	Loss: 0.148055
# Train Epoch: 4 [25600/34799 (74%)]	Loss per example: 0.000237	Loss: 0.151934
# Train Epoch: 4 [26240/34799 (75%)]	Loss per example: 0.000207	Loss: 0.132433
# Train Epoch: 4 [26880/34799 (77%)]	Loss per example: 0.000217	Loss: 0.138934
# Train Epoch: 4 [27520/34799 (79%)]	Loss per example: 0.000298	Loss: 0.190699
# Train Epoch: 4 [28160/34799 (81%)]	Loss per example: 0.000289	Loss: 0.185007
# Train Epoch: 4 [28800/34799 (83%)]	Loss per example: 0.000242	Loss: 0.155045
# Train Epoch: 4 [29440/34799 (85%)]	Loss per example: 0.000231	Loss: 0.147863
# Train Epoch: 4 [30080/34799 (86%)]	Loss per example: 0.000184	Loss: 0.118040
# Train Epoch: 4 [30720/34799 (88%)]	Loss per example: 0.000209	Loss: 0.133527
# Train Epoch: 4 [31360/34799 (90%)]	Loss per example: 0.000210	Loss: 0.134228
# Train Epoch: 4 [32000/34799 (92%)]	Loss per example: 0.000243	Loss: 0.155466
# Train Epoch: 4 [32640/34799 (94%)]	Loss per example: 0.000320	Loss: 0.204761
# Train Epoch: 4 [33280/34799 (96%)]	Loss per example: 0.000302	Loss: 0.193243
# Train Epoch: 4 [33920/34799 (97%)]	Loss per example: 0.000248	Loss: 0.159037
# Train Epoch: 4 [34560/34799 (99%)]	Loss per example: 0.000274	Loss: 0.175193
#
# Training set: Average loss: 0.0027, Accuracy: 33076/34799 (95%)
#
#
# Validation set: Average loss: 2.9352, Accuracy: 4284/4410 (97%)
#
# Train Epoch: 5 [0/34799 (0%)]	Loss per example: 0.000283	Loss: 0.181144
# Train Epoch: 5 [640/34799 (2%)]	Loss per example: 0.000177	Loss: 0.113441
# Train Epoch: 5 [1280/34799 (4%)]	Loss per example: 0.000356	Loss: 0.227844
# Train Epoch: 5 [1920/34799 (6%)]	Loss per example: 0.000189	Loss: 0.120837
# Train Epoch: 5 [2560/34799 (7%)]	Loss per example: 0.000223	Loss: 0.142814
# Train Epoch: 5 [3200/34799 (9%)]	Loss per example: 0.000239	Loss: 0.152643
# Train Epoch: 5 [3840/34799 (11%)]	Loss per example: 0.000208	Loss: 0.133032
# Train Epoch: 5 [4480/34799 (13%)]	Loss per example: 0.000244	Loss: 0.156206
# Train Epoch: 5 [5120/34799 (15%)]	Loss per example: 0.000236	Loss: 0.151063
# Train Epoch: 5 [5760/34799 (17%)]	Loss per example: 0.000218	Loss: 0.139687
# Train Epoch: 5 [6400/34799 (18%)]	Loss per example: 0.000284	Loss: 0.181540
# Train Epoch: 5 [7040/34799 (20%)]	Loss per example: 0.000199	Loss: 0.127108
# Train Epoch: 5 [7680/34799 (22%)]	Loss per example: 0.000231	Loss: 0.147723
# Train Epoch: 5 [8320/34799 (24%)]	Loss per example: 0.000225	Loss: 0.143852
# Train Epoch: 5 [8960/34799 (26%)]	Loss per example: 0.000252	Loss: 0.160970
# Train Epoch: 5 [9600/34799 (28%)]	Loss per example: 0.000220	Loss: 0.140675
# Train Epoch: 5 [10240/34799 (29%)]	Loss per example: 0.000196	Loss: 0.125739
# Train Epoch: 5 [10880/34799 (31%)]	Loss per example: 0.000247	Loss: 0.158148
# Train Epoch: 5 [11520/34799 (33%)]	Loss per example: 0.000281	Loss: 0.180150
# Train Epoch: 5 [12160/34799 (35%)]	Loss per example: 0.000261	Loss: 0.167180
# Train Epoch: 5 [12800/34799 (37%)]	Loss per example: 0.000258	Loss: 0.164980
# Train Epoch: 5 [13440/34799 (39%)]	Loss per example: 0.000272	Loss: 0.174282
# Train Epoch: 5 [14080/34799 (40%)]	Loss per example: 0.000215	Loss: 0.137517
# Train Epoch: 5 [14720/34799 (42%)]	Loss per example: 0.000215	Loss: 0.137806
# Train Epoch: 5 [15360/34799 (44%)]	Loss per example: 0.000220	Loss: 0.140706
# Train Epoch: 5 [16000/34799 (46%)]	Loss per example: 0.000211	Loss: 0.135327
# Train Epoch: 5 [16640/34799 (48%)]	Loss per example: 0.000239	Loss: 0.152874
# Train Epoch: 5 [17280/34799 (50%)]	Loss per example: 0.000208	Loss: 0.133198
# Train Epoch: 5 [17920/34799 (51%)]	Loss per example: 0.000214	Loss: 0.137228
# Train Epoch: 5 [18560/34799 (53%)]	Loss per example: 0.000204	Loss: 0.130717
# Train Epoch: 5 [19200/34799 (55%)]	Loss per example: 0.000226	Loss: 0.144464
# Train Epoch: 5 [19840/34799 (57%)]	Loss per example: 0.000306	Loss: 0.195927
# Train Epoch: 5 [20480/34799 (59%)]	Loss per example: 0.000294	Loss: 0.187958
# Train Epoch: 5 [21120/34799 (61%)]	Loss per example: 0.000213	Loss: 0.136394
# Train Epoch: 5 [21760/34799 (62%)]	Loss per example: 0.000220	Loss: 0.141090
# Train Epoch: 5 [22400/34799 (64%)]	Loss per example: 0.000187	Loss: 0.119416
# Train Epoch: 5 [23040/34799 (66%)]	Loss per example: 0.000246	Loss: 0.157139
# Train Epoch: 5 [23680/34799 (68%)]	Loss per example: 0.000223	Loss: 0.142751
# Train Epoch: 5 [24320/34799 (70%)]	Loss per example: 0.000215	Loss: 0.137676
# Train Epoch: 5 [24960/34799 (72%)]	Loss per example: 0.000263	Loss: 0.168038
# Train Epoch: 5 [25600/34799 (74%)]	Loss per example: 0.000271	Loss: 0.173314
# Train Epoch: 5 [26240/34799 (75%)]	Loss per example: 0.000264	Loss: 0.169137
# Train Epoch: 5 [26880/34799 (77%)]	Loss per example: 0.000235	Loss: 0.150591
# Train Epoch: 5 [27520/34799 (79%)]	Loss per example: 0.000261	Loss: 0.167305
# Train Epoch: 5 [28160/34799 (81%)]	Loss per example: 0.000228	Loss: 0.145785
# Train Epoch: 5 [28800/34799 (83%)]	Loss per example: 0.000254	Loss: 0.162842
# Train Epoch: 5 [29440/34799 (85%)]	Loss per example: 0.000191	Loss: 0.122205
# Train Epoch: 5 [30080/34799 (86%)]	Loss per example: 0.000236	Loss: 0.151063
# Train Epoch: 5 [30720/34799 (88%)]	Loss per example: 0.000264	Loss: 0.168979
# Train Epoch: 5 [31360/34799 (90%)]	Loss per example: 0.000252	Loss: 0.161396
# Train Epoch: 5 [32000/34799 (92%)]	Loss per example: 0.000187	Loss: 0.119760
# Train Epoch: 5 [32640/34799 (94%)]	Loss per example: 0.000225	Loss: 0.143709
# Train Epoch: 5 [33280/34799 (96%)]	Loss per example: 0.000204	Loss: 0.130272
# Train Epoch: 5 [33920/34799 (97%)]	Loss per example: 0.000182	Loss: 0.116200
# Train Epoch: 5 [34560/34799 (99%)]	Loss per example: 0.000186	Loss: 0.119132
#
# Training set: Average loss: 0.0024, Accuracy: 33610/34799 (97%)
#
#
# Validation set: Average loss: 2.9262, Accuracy: 4294/4410 (97%)
#
# Train Epoch: 6 [0/34799 (0%)]	Loss per example: 0.000210	Loss: 0.134541
# Train Epoch: 6 [640/34799 (2%)]	Loss per example: 0.000282	Loss: 0.180740
# Train Epoch: 6 [1280/34799 (4%)]	Loss per example: 0.000234	Loss: 0.150007
# Train Epoch: 6 [1920/34799 (6%)]	Loss per example: 0.000238	Loss: 0.152439
# Train Epoch: 6 [2560/34799 (7%)]	Loss per example: 0.000288	Loss: 0.184572
# Train Epoch: 6 [3200/34799 (9%)]	Loss per example: 0.000168	Loss: 0.107423
# Train Epoch: 6 [3840/34799 (11%)]	Loss per example: 0.000243	Loss: 0.155271
# Train Epoch: 6 [4480/34799 (13%)]	Loss per example: 0.000311	Loss: 0.198809
# Train Epoch: 6 [5120/34799 (15%)]	Loss per example: 0.000205	Loss: 0.130951
# Train Epoch: 6 [5760/34799 (17%)]	Loss per example: 0.000207	Loss: 0.132643
# Train Epoch: 6 [6400/34799 (18%)]	Loss per example: 0.000190	Loss: 0.121394
# Train Epoch: 6 [7040/34799 (20%)]	Loss per example: 0.000423	Loss: 0.270559
# Train Epoch: 6 [7680/34799 (22%)]	Loss per example: 0.000264	Loss: 0.168771
# Train Epoch: 6 [8320/34799 (24%)]	Loss per example: 0.000265	Loss: 0.169344
# Train Epoch: 6 [8960/34799 (26%)]	Loss per example: 0.000200	Loss: 0.128144
# Train Epoch: 6 [9600/34799 (28%)]	Loss per example: 0.000236	Loss: 0.151089
# Train Epoch: 6 [10240/34799 (29%)]	Loss per example: 0.000197	Loss: 0.126399
# Train Epoch: 6 [10880/34799 (31%)]	Loss per example: 0.000214	Loss: 0.136727
# Train Epoch: 6 [11520/34799 (33%)]	Loss per example: 0.000183	Loss: 0.116874
# Train Epoch: 6 [12160/34799 (35%)]	Loss per example: 0.000362	Loss: 0.231521
# Train Epoch: 6 [12800/34799 (37%)]	Loss per example: 0.000174	Loss: 0.111359
# Train Epoch: 6 [13440/34799 (39%)]	Loss per example: 0.000270	Loss: 0.172985
# Train Epoch: 6 [14080/34799 (40%)]	Loss per example: 0.000216	Loss: 0.137939
# Train Epoch: 6 [14720/34799 (42%)]	Loss per example: 0.000216	Loss: 0.138038
# Train Epoch: 6 [15360/34799 (44%)]	Loss per example: 0.000267	Loss: 0.170678
# Train Epoch: 6 [16000/34799 (46%)]	Loss per example: 0.000208	Loss: 0.132939
# Train Epoch: 6 [16640/34799 (48%)]	Loss per example: 0.000220	Loss: 0.141066
# Train Epoch: 6 [17280/34799 (50%)]	Loss per example: 0.000206	Loss: 0.132081
# Train Epoch: 6 [17920/34799 (51%)]	Loss per example: 0.000225	Loss: 0.144230
# Train Epoch: 6 [18560/34799 (53%)]	Loss per example: 0.000238	Loss: 0.152430
# Train Epoch: 6 [19200/34799 (55%)]	Loss per example: 0.000204	Loss: 0.130864
# Train Epoch: 6 [19840/34799 (57%)]	Loss per example: 0.000235	Loss: 0.150466
# Train Epoch: 6 [20480/34799 (59%)]	Loss per example: 0.000223	Loss: 0.142828
# Train Epoch: 6 [21120/34799 (61%)]	Loss per example: 0.000225	Loss: 0.143994
# Train Epoch: 6 [21760/34799 (62%)]	Loss per example: 0.000183	Loss: 0.117279
# Train Epoch: 6 [22400/34799 (64%)]	Loss per example: 0.000217	Loss: 0.138608
# Train Epoch: 6 [23040/34799 (66%)]	Loss per example: 0.000207	Loss: 0.132737
# Train Epoch: 6 [23680/34799 (68%)]	Loss per example: 0.000215	Loss: 0.137326
# Train Epoch: 6 [24320/34799 (70%)]	Loss per example: 0.000201	Loss: 0.128693
# Train Epoch: 6 [24960/34799 (72%)]	Loss per example: 0.000304	Loss: 0.194252
# Train Epoch: 6 [25600/34799 (74%)]	Loss per example: 0.000235	Loss: 0.150366
# Train Epoch: 6 [26240/34799 (75%)]	Loss per example: 0.000264	Loss: 0.168825
# Train Epoch: 6 [26880/34799 (77%)]	Loss per example: 0.000299	Loss: 0.191473
# Train Epoch: 6 [27520/34799 (79%)]	Loss per example: 0.000236	Loss: 0.151154
# Train Epoch: 6 [28160/34799 (81%)]	Loss per example: 0.000205	Loss: 0.131184
# Train Epoch: 6 [28800/34799 (83%)]	Loss per example: 0.000270	Loss: 0.172968
# Train Epoch: 6 [29440/34799 (85%)]	Loss per example: 0.000196	Loss: 0.125654
# Train Epoch: 6 [30080/34799 (86%)]	Loss per example: 0.000220	Loss: 0.140705
# Train Epoch: 6 [30720/34799 (88%)]	Loss per example: 0.000205	Loss: 0.131130
# Train Epoch: 6 [31360/34799 (90%)]	Loss per example: 0.000235	Loss: 0.150108
# Train Epoch: 6 [32000/34799 (92%)]	Loss per example: 0.000186	Loss: 0.119339
# Train Epoch: 6 [32640/34799 (94%)]	Loss per example: 0.000207	Loss: 0.132269
# Train Epoch: 6 [33280/34799 (96%)]	Loss per example: 0.000212	Loss: 0.135547
# Train Epoch: 6 [33920/34799 (97%)]	Loss per example: 0.000241	Loss: 0.154264
# Train Epoch: 6 [34560/34799 (99%)]	Loss per example: 0.000213	Loss: 0.136107
#
# Training set: Average loss: 0.0023, Accuracy: 33792/34799 (97%)
#
#
# Validation set: Average loss: 2.9197, Accuracy: 4283/4410 (97%)
#
# Train Epoch: 7 [0/34799 (0%)]	Loss per example: 0.000224	Loss: 0.143546
# Train Epoch: 7 [640/34799 (2%)]	Loss per example: 0.000198	Loss: 0.126408
# Train Epoch: 7 [1280/34799 (4%)]	Loss per example: 0.000199	Loss: 0.127271
# Train Epoch: 7 [1920/34799 (6%)]	Loss per example: 0.000215	Loss: 0.137372
# Train Epoch: 7 [2560/34799 (7%)]	Loss per example: 0.000324	Loss: 0.207210
# Train Epoch: 7 [3200/34799 (9%)]	Loss per example: 0.000174	Loss: 0.111406
# Train Epoch: 7 [3840/34799 (11%)]	Loss per example: 0.000211	Loss: 0.135288
# Train Epoch: 7 [4480/34799 (13%)]	Loss per example: 0.000221	Loss: 0.141121
# Train Epoch: 7 [5120/34799 (15%)]	Loss per example: 0.000194	Loss: 0.124297
# Train Epoch: 7 [5760/34799 (17%)]	Loss per example: 0.000218	Loss: 0.139454
# Train Epoch: 7 [6400/34799 (18%)]	Loss per example: 0.000188	Loss: 0.120386
# Train Epoch: 7 [7040/34799 (20%)]	Loss per example: 0.000207	Loss: 0.132454
# Train Epoch: 7 [7680/34799 (22%)]	Loss per example: 0.000236	Loss: 0.150852
# Train Epoch: 7 [8320/34799 (24%)]	Loss per example: 0.000256	Loss: 0.163964
# Train Epoch: 7 [8960/34799 (26%)]	Loss per example: 0.000287	Loss: 0.183587
# Train Epoch: 7 [9600/34799 (28%)]	Loss per example: 0.000257	Loss: 0.164530
# Train Epoch: 7 [10240/34799 (29%)]	Loss per example: 0.000235	Loss: 0.150108
# Train Epoch: 7 [10880/34799 (31%)]	Loss per example: 0.000230	Loss: 0.147508
# Train Epoch: 7 [11520/34799 (33%)]	Loss per example: 0.000197	Loss: 0.126036
# Train Epoch: 7 [12160/34799 (35%)]	Loss per example: 0.000226	Loss: 0.144865
# Train Epoch: 7 [12800/34799 (37%)]	Loss per example: 0.000264	Loss: 0.168770
# Train Epoch: 7 [13440/34799 (39%)]	Loss per example: 0.000216	Loss: 0.138079
# Train Epoch: 7 [14080/34799 (40%)]	Loss per example: 0.000262	Loss: 0.167443
# Train Epoch: 7 [14720/34799 (42%)]	Loss per example: 0.000197	Loss: 0.125769
# Train Epoch: 7 [15360/34799 (44%)]	Loss per example: 0.000192	Loss: 0.122801
# Train Epoch: 7 [16000/34799 (46%)]	Loss per example: 0.000216	Loss: 0.138095
# Train Epoch: 7 [16640/34799 (48%)]	Loss per example: 0.000223	Loss: 0.142733
# Train Epoch: 7 [17280/34799 (50%)]	Loss per example: 0.000208	Loss: 0.132819
# Train Epoch: 7 [17920/34799 (51%)]	Loss per example: 0.000194	Loss: 0.124102
# Train Epoch: 7 [18560/34799 (53%)]	Loss per example: 0.000234	Loss: 0.149956
# Train Epoch: 7 [19200/34799 (55%)]	Loss per example: 0.000179	Loss: 0.114674
# Train Epoch: 7 [19840/34799 (57%)]	Loss per example: 0.000180	Loss: 0.115375
# Train Epoch: 7 [20480/34799 (59%)]	Loss per example: 0.000218	Loss: 0.139554
# Train Epoch: 7 [21120/34799 (61%)]	Loss per example: 0.000214	Loss: 0.136867
# Train Epoch: 7 [21760/34799 (62%)]	Loss per example: 0.000204	Loss: 0.130741
# Train Epoch: 7 [22400/34799 (64%)]	Loss per example: 0.000187	Loss: 0.119811
# Train Epoch: 7 [23040/34799 (66%)]	Loss per example: 0.000257	Loss: 0.164707
# Train Epoch: 7 [23680/34799 (68%)]	Loss per example: 0.000196	Loss: 0.125507
# Train Epoch: 7 [24320/34799 (70%)]	Loss per example: 0.000224	Loss: 0.143503
# Train Epoch: 7 [24960/34799 (72%)]	Loss per example: 0.000209	Loss: 0.133936
# Train Epoch: 7 [25600/34799 (74%)]	Loss per example: 0.000193	Loss: 0.123442
# Train Epoch: 7 [26240/34799 (75%)]	Loss per example: 0.000228	Loss: 0.146050
# Train Epoch: 7 [26880/34799 (77%)]	Loss per example: 0.000250	Loss: 0.160145
# Train Epoch: 7 [27520/34799 (79%)]	Loss per example: 0.000228	Loss: 0.145607
# Train Epoch: 7 [28160/34799 (81%)]	Loss per example: 0.000234	Loss: 0.149497
# Train Epoch: 7 [28800/34799 (83%)]	Loss per example: 0.000198	Loss: 0.126412
# Train Epoch: 7 [29440/34799 (85%)]	Loss per example: 0.000177	Loss: 0.113327
# Train Epoch: 7 [30080/34799 (86%)]	Loss per example: 0.000208	Loss: 0.133366
# Train Epoch: 7 [30720/34799 (88%)]	Loss per example: 0.000173	Loss: 0.110544
# Train Epoch: 7 [31360/34799 (90%)]	Loss per example: 0.000263	Loss: 0.168597
# Train Epoch: 7 [32000/34799 (92%)]	Loss per example: 0.000339	Loss: 0.216726
# Train Epoch: 7 [32640/34799 (94%)]	Loss per example: 0.000216	Loss: 0.138339
# Train Epoch: 7 [33280/34799 (96%)]	Loss per example: 0.000161	Loss: 0.103045
# Train Epoch: 7 [33920/34799 (97%)]	Loss per example: 0.000216	Loss: 0.138372
# Train Epoch: 7 [34560/34799 (99%)]	Loss per example: 0.000237	Loss: 0.151927
#
# Training set: Average loss: 0.0022, Accuracy: 33949/34799 (98%)
#
#
# Validation set: Average loss: 2.9270, Accuracy: 4291/4410 (97%)
#
# Train Epoch: 8 [0/34799 (0%)]	Loss per example: 0.000273	Loss: 0.175024
# Train Epoch: 8 [640/34799 (2%)]	Loss per example: 0.000285	Loss: 0.182505
# Train Epoch: 8 [1280/34799 (4%)]	Loss per example: 0.000198	Loss: 0.127019
# Train Epoch: 8 [1920/34799 (6%)]	Loss per example: 0.000252	Loss: 0.161304
# Train Epoch: 8 [2560/34799 (7%)]	Loss per example: 0.000233	Loss: 0.149397
# Train Epoch: 8 [3200/34799 (9%)]	Loss per example: 0.000204	Loss: 0.130252
# Train Epoch: 8 [3840/34799 (11%)]	Loss per example: 0.000184	Loss: 0.117513
# Train Epoch: 8 [4480/34799 (13%)]	Loss per example: 0.000175	Loss: 0.111842
# Train Epoch: 8 [5120/34799 (15%)]	Loss per example: 0.000178	Loss: 0.113843
# Train Epoch: 8 [5760/34799 (17%)]	Loss per example: 0.000220	Loss: 0.140602
# Train Epoch: 8 [6400/34799 (18%)]	Loss per example: 0.000196	Loss: 0.125716
# Train Epoch: 8 [7040/34799 (20%)]	Loss per example: 0.000216	Loss: 0.138351
# Train Epoch: 8 [7680/34799 (22%)]	Loss per example: 0.000260	Loss: 0.166297
# Train Epoch: 8 [8320/34799 (24%)]	Loss per example: 0.000224	Loss: 0.143164
# Train Epoch: 8 [8960/34799 (26%)]	Loss per example: 0.000232	Loss: 0.148187
# Train Epoch: 8 [9600/34799 (28%)]	Loss per example: 0.000200	Loss: 0.128042
# Train Epoch: 8 [10240/34799 (29%)]	Loss per example: 0.000279	Loss: 0.178423
# Train Epoch: 8 [10880/34799 (31%)]	Loss per example: 0.000196	Loss: 0.125349
# Train Epoch: 8 [11520/34799 (33%)]	Loss per example: 0.000189	Loss: 0.120674
# Train Epoch: 8 [12160/34799 (35%)]	Loss per example: 0.000224	Loss: 0.143063
# Train Epoch: 8 [12800/34799 (37%)]	Loss per example: 0.000222	Loss: 0.142155
# Train Epoch: 8 [13440/34799 (39%)]	Loss per example: 0.000223	Loss: 0.142602
# Train Epoch: 8 [14080/34799 (40%)]	Loss per example: 0.000271	Loss: 0.173545
# Train Epoch: 8 [14720/34799 (42%)]	Loss per example: 0.000214	Loss: 0.136905
# Train Epoch: 8 [15360/34799 (44%)]	Loss per example: 0.000262	Loss: 0.167882
# Train Epoch: 8 [16000/34799 (46%)]	Loss per example: 0.000176	Loss: 0.112519
# Train Epoch: 8 [16640/34799 (48%)]	Loss per example: 0.000219	Loss: 0.139906
# Train Epoch: 8 [17280/34799 (50%)]	Loss per example: 0.000182	Loss: 0.116411
# Train Epoch: 8 [17920/34799 (51%)]	Loss per example: 0.000198	Loss: 0.126876
# Train Epoch: 8 [18560/34799 (53%)]	Loss per example: 0.000321	Loss: 0.205219
# Train Epoch: 8 [19200/34799 (55%)]	Loss per example: 0.000274	Loss: 0.175194
# Train Epoch: 8 [19840/34799 (57%)]	Loss per example: 0.000198	Loss: 0.126588
# Train Epoch: 8 [20480/34799 (59%)]	Loss per example: 0.000279	Loss: 0.178414
# Train Epoch: 8 [21120/34799 (61%)]	Loss per example: 0.000201	Loss: 0.128707
# Train Epoch: 8 [21760/34799 (62%)]	Loss per example: 0.000200	Loss: 0.127925
# Train Epoch: 8 [22400/34799 (64%)]	Loss per example: 0.000228	Loss: 0.145928
# Train Epoch: 8 [23040/34799 (66%)]	Loss per example: 0.000227	Loss: 0.145432
# Train Epoch: 8 [23680/34799 (68%)]	Loss per example: 0.000256	Loss: 0.163581
# Train Epoch: 8 [24320/34799 (70%)]	Loss per example: 0.000189	Loss: 0.120984
# Train Epoch: 8 [24960/34799 (72%)]	Loss per example: 0.000212	Loss: 0.135872
# Train Epoch: 8 [25600/34799 (74%)]	Loss per example: 0.000232	Loss: 0.148331
# Train Epoch: 8 [26240/34799 (75%)]	Loss per example: 0.000234	Loss: 0.149805
# Train Epoch: 8 [26880/34799 (77%)]	Loss per example: 0.000205	Loss: 0.130963
# Train Epoch: 8 [27520/34799 (79%)]	Loss per example: 0.000209	Loss: 0.133843
# Train Epoch: 8 [28160/34799 (81%)]	Loss per example: 0.000232	Loss: 0.148341
# Train Epoch: 8 [28800/34799 (83%)]	Loss per example: 0.000169	Loss: 0.107947
# Train Epoch: 8 [29440/34799 (85%)]	Loss per example: 0.000229	Loss: 0.146624
# Train Epoch: 8 [30080/34799 (86%)]	Loss per example: 0.000196	Loss: 0.125505
# Train Epoch: 8 [30720/34799 (88%)]	Loss per example: 0.000210	Loss: 0.134633
# Train Epoch: 8 [31360/34799 (90%)]	Loss per example: 0.000223	Loss: 0.142443
# Train Epoch: 8 [32000/34799 (92%)]	Loss per example: 0.000231	Loss: 0.147908
# Train Epoch: 8 [32640/34799 (94%)]	Loss per example: 0.000238	Loss: 0.152599
# Train Epoch: 8 [33280/34799 (96%)]	Loss per example: 0.000196	Loss: 0.125316
# Train Epoch: 8 [33920/34799 (97%)]	Loss per example: 0.000270	Loss: 0.173008
# Train Epoch: 8 [34560/34799 (99%)]	Loss per example: 0.000346	Loss: 0.221299
#
# Training set: Average loss: 0.0022, Accuracy: 33978/34799 (98%)
#
#
# Validation set: Average loss: 2.9254, Accuracy: 4283/4410 (97%)
#
# Train Epoch: 9 [0/34799 (0%)]	Loss per example: 0.000258	Loss: 0.165289
# Train Epoch: 9 [640/34799 (2%)]	Loss per example: 0.000175	Loss: 0.111721
# Train Epoch: 9 [1280/34799 (4%)]	Loss per example: 0.000250	Loss: 0.160251
# Train Epoch: 9 [1920/34799 (6%)]	Loss per example: 0.000223	Loss: 0.142779
# Train Epoch: 9 [2560/34799 (7%)]	Loss per example: 0.000200	Loss: 0.127891
# Train Epoch: 9 [3200/34799 (9%)]	Loss per example: 0.000258	Loss: 0.165177
# Train Epoch: 9 [3840/34799 (11%)]	Loss per example: 0.000201	Loss: 0.128431
# Train Epoch: 9 [4480/34799 (13%)]	Loss per example: 0.000189	Loss: 0.120897
# Train Epoch: 9 [5120/34799 (15%)]	Loss per example: 0.000179	Loss: 0.114870
# Train Epoch: 9 [5760/34799 (17%)]	Loss per example: 0.000210	Loss: 0.134586
# Train Epoch: 9 [6400/34799 (18%)]	Loss per example: 0.000171	Loss: 0.109732
# Train Epoch: 9 [7040/34799 (20%)]	Loss per example: 0.000214	Loss: 0.137084
# Train Epoch: 9 [7680/34799 (22%)]	Loss per example: 0.000160	Loss: 0.102167
# Train Epoch: 9 [8320/34799 (24%)]	Loss per example: 0.000178	Loss: 0.113657
# Train Epoch: 9 [8960/34799 (26%)]	Loss per example: 0.000260	Loss: 0.166472
# Train Epoch: 9 [9600/34799 (28%)]	Loss per example: 0.000205	Loss: 0.131114
# Train Epoch: 9 [10240/34799 (29%)]	Loss per example: 0.000218	Loss: 0.139608
# Train Epoch: 9 [10880/34799 (31%)]	Loss per example: 0.000189	Loss: 0.120655
# Train Epoch: 9 [11520/34799 (33%)]	Loss per example: 0.000181	Loss: 0.115607
# Train Epoch: 9 [12160/34799 (35%)]	Loss per example: 0.000291	Loss: 0.186254
# Train Epoch: 9 [12800/34799 (37%)]	Loss per example: 0.000192	Loss: 0.123012
# Train Epoch: 9 [13440/34799 (39%)]	Loss per example: 0.000189	Loss: 0.121194
# Train Epoch: 9 [14080/34799 (40%)]	Loss per example: 0.000237	Loss: 0.151443
# Train Epoch: 9 [14720/34799 (42%)]	Loss per example: 0.000206	Loss: 0.131762
# Train Epoch: 9 [15360/34799 (44%)]	Loss per example: 0.000211	Loss: 0.135345
# Train Epoch: 9 [16000/34799 (46%)]	Loss per example: 0.000188	Loss: 0.120411
# Train Epoch: 9 [16640/34799 (48%)]	Loss per example: 0.000213	Loss: 0.136039
# Train Epoch: 9 [17280/34799 (50%)]	Loss per example: 0.000212	Loss: 0.135824
# Train Epoch: 9 [17920/34799 (51%)]	Loss per example: 0.000225	Loss: 0.143809
# Train Epoch: 9 [18560/34799 (53%)]	Loss per example: 0.000191	Loss: 0.122311
# Train Epoch: 9 [19200/34799 (55%)]	Loss per example: 0.000155	Loss: 0.098950
# Train Epoch: 9 [19840/34799 (57%)]	Loss per example: 0.000185	Loss: 0.118153
# Train Epoch: 9 [20480/34799 (59%)]	Loss per example: 0.000219	Loss: 0.140466
# Train Epoch: 9 [21120/34799 (61%)]	Loss per example: 0.000182	Loss: 0.116512
# Train Epoch: 9 [21760/34799 (62%)]	Loss per example: 0.000200	Loss: 0.128130
# Train Epoch: 9 [22400/34799 (64%)]	Loss per example: 0.000212	Loss: 0.135600
# Train Epoch: 9 [23040/34799 (66%)]	Loss per example: 0.000237	Loss: 0.151496
# Train Epoch: 9 [23680/34799 (68%)]	Loss per example: 0.000191	Loss: 0.122353
# Train Epoch: 9 [24320/34799 (70%)]	Loss per example: 0.000176	Loss: 0.112717
# Train Epoch: 9 [24960/34799 (72%)]	Loss per example: 0.000230	Loss: 0.147449
# Train Epoch: 9 [25600/34799 (74%)]	Loss per example: 0.000227	Loss: 0.145319
# Train Epoch: 9 [26240/34799 (75%)]	Loss per example: 0.000203	Loss: 0.130187
# Train Epoch: 9 [26880/34799 (77%)]	Loss per example: 0.000278	Loss: 0.178147
# Train Epoch: 9 [27520/34799 (79%)]	Loss per example: 0.000237	Loss: 0.151545
# Train Epoch: 9 [28160/34799 (81%)]	Loss per example: 0.000200	Loss: 0.128014
# Train Epoch: 9 [28800/34799 (83%)]	Loss per example: 0.000191	Loss: 0.122428
# Train Epoch: 9 [29440/34799 (85%)]	Loss per example: 0.000182	Loss: 0.116498
# Train Epoch: 9 [30080/34799 (86%)]	Loss per example: 0.000187	Loss: 0.119630
# Train Epoch: 9 [30720/34799 (88%)]	Loss per example: 0.000229	Loss: 0.146474
# Train Epoch: 9 [31360/34799 (90%)]	Loss per example: 0.000201	Loss: 0.128861
# Train Epoch: 9 [32000/34799 (92%)]	Loss per example: 0.000205	Loss: 0.131316
# Train Epoch: 9 [32640/34799 (94%)]	Loss per example: 0.000212	Loss: 0.135797
# Train Epoch: 9 [33280/34799 (96%)]	Loss per example: 0.000217	Loss: 0.138812
# Train Epoch: 9 [33920/34799 (97%)]	Loss per example: 0.000179	Loss: 0.114709
# Train Epoch: 9 [34560/34799 (99%)]	Loss per example: 0.000181	Loss: 0.115893
#
# Training set: Average loss: 0.0021, Accuracy: 34036/34799 (98%)
#
# Epoch     9: reducing learning rate of group 0 to 5.0000e-04.
#
# Validation set: Average loss: 2.9179, Accuracy: 4296/4410 (97%)
#
# Train Epoch: 10 [0/34799 (0%)]	Loss per example: 0.000232	Loss: 0.148231
# Train Epoch: 10 [640/34799 (2%)]	Loss per example: 0.000183	Loss: 0.116977
# Train Epoch: 10 [1280/34799 (4%)]	Loss per example: 0.000218	Loss: 0.139395
# Train Epoch: 10 [1920/34799 (6%)]	Loss per example: 0.000183	Loss: 0.117430
# Train Epoch: 10 [2560/34799 (7%)]	Loss per example: 0.000190	Loss: 0.121731
# Train Epoch: 10 [3200/34799 (9%)]	Loss per example: 0.000206	Loss: 0.131933
# Train Epoch: 10 [3840/34799 (11%)]	Loss per example: 0.000160	Loss: 0.102426
# Train Epoch: 10 [4480/34799 (13%)]	Loss per example: 0.000194	Loss: 0.124333
# Train Epoch: 10 [5120/34799 (15%)]	Loss per example: 0.000170	Loss: 0.108901
# Train Epoch: 10 [5760/34799 (17%)]	Loss per example: 0.000161	Loss: 0.102987
# Train Epoch: 10 [6400/34799 (18%)]	Loss per example: 0.000163	Loss: 0.104055
# Train Epoch: 10 [7040/34799 (20%)]	Loss per example: 0.000222	Loss: 0.142299
# Train Epoch: 10 [7680/34799 (22%)]	Loss per example: 0.000242	Loss: 0.154965
# Train Epoch: 10 [8320/34799 (24%)]	Loss per example: 0.000172	Loss: 0.109813
# Train Epoch: 10 [8960/34799 (26%)]	Loss per example: 0.000195	Loss: 0.124792
# Train Epoch: 10 [9600/34799 (28%)]	Loss per example: 0.000169	Loss: 0.108131
# Train Epoch: 10 [10240/34799 (29%)]	Loss per example: 0.000174	Loss: 0.111544
# Train Epoch: 10 [10880/34799 (31%)]	Loss per example: 0.000176	Loss: 0.112774
# Train Epoch: 10 [11520/34799 (33%)]	Loss per example: 0.000193	Loss: 0.123231
# Train Epoch: 10 [12160/34799 (35%)]	Loss per example: 0.000158	Loss: 0.101224
# Train Epoch: 10 [12800/34799 (37%)]	Loss per example: 0.000151	Loss: 0.096959
# Train Epoch: 10 [13440/34799 (39%)]	Loss per example: 0.000204	Loss: 0.130366
# Train Epoch: 10 [14080/34799 (40%)]	Loss per example: 0.000175	Loss: 0.112254
# Train Epoch: 10 [14720/34799 (42%)]	Loss per example: 0.000176	Loss: 0.112768
# Train Epoch: 10 [15360/34799 (44%)]	Loss per example: 0.000154	Loss: 0.098633
# Train Epoch: 10 [16000/34799 (46%)]	Loss per example: 0.000191	Loss: 0.122271
# Train Epoch: 10 [16640/34799 (48%)]	Loss per example: 0.000149	Loss: 0.095266
# Train Epoch: 10 [17280/34799 (50%)]	Loss per example: 0.000204	Loss: 0.130578
# Train Epoch: 10 [17920/34799 (51%)]	Loss per example: 0.000185	Loss: 0.118711
# Train Epoch: 10 [18560/34799 (53%)]	Loss per example: 0.000256	Loss: 0.163815
# Train Epoch: 10 [19200/34799 (55%)]	Loss per example: 0.000222	Loss: 0.142398
# Train Epoch: 10 [19840/34799 (57%)]	Loss per example: 0.000183	Loss: 0.117335
# Train Epoch: 10 [20480/34799 (59%)]	Loss per example: 0.000150	Loss: 0.095945
# Train Epoch: 10 [21120/34799 (61%)]	Loss per example: 0.000226	Loss: 0.144471
# Train Epoch: 10 [21760/34799 (62%)]	Loss per example: 0.000189	Loss: 0.120940
# Train Epoch: 10 [22400/34799 (64%)]	Loss per example: 0.000164	Loss: 0.104951
# Train Epoch: 10 [23040/34799 (66%)]	Loss per example: 0.000178	Loss: 0.114034
# Train Epoch: 10 [23680/34799 (68%)]	Loss per example: 0.000235	Loss: 0.150268
# Train Epoch: 10 [24320/34799 (70%)]	Loss per example: 0.000163	Loss: 0.104496
# Train Epoch: 10 [24960/34799 (72%)]	Loss per example: 0.000152	Loss: 0.097366
# Train Epoch: 10 [25600/34799 (74%)]	Loss per example: 0.000153	Loss: 0.098071
# Train Epoch: 10 [26240/34799 (75%)]	Loss per example: 0.000168	Loss: 0.107317
# Train Epoch: 10 [26880/34799 (77%)]	Loss per example: 0.000274	Loss: 0.175450
# Train Epoch: 10 [27520/34799 (79%)]	Loss per example: 0.000171	Loss: 0.109370
# Train Epoch: 10 [28160/34799 (81%)]	Loss per example: 0.000202	Loss: 0.129583
# Train Epoch: 10 [28800/34799 (83%)]	Loss per example: 0.000186	Loss: 0.118730
# Train Epoch: 10 [29440/34799 (85%)]	Loss per example: 0.000177	Loss: 0.113213
# Train Epoch: 10 [30080/34799 (86%)]	Loss per example: 0.000195	Loss: 0.125078
# Train Epoch: 10 [30720/34799 (88%)]	Loss per example: 0.000182	Loss: 0.116360
# Train Epoch: 10 [31360/34799 (90%)]	Loss per example: 0.000197	Loss: 0.125861
# Train Epoch: 10 [32000/34799 (92%)]	Loss per example: 0.000178	Loss: 0.113758
# Train Epoch: 10 [32640/34799 (94%)]	Loss per example: 0.000176	Loss: 0.112345
# Train Epoch: 10 [33280/34799 (96%)]	Loss per example: 0.000171	Loss: 0.109252
# Train Epoch: 10 [33920/34799 (97%)]	Loss per example: 0.000169	Loss: 0.108091
# Train Epoch: 10 [34560/34799 (99%)]	Loss per example: 0.000155	Loss: 0.099144
#
# Training set: Average loss: 0.0018, Accuracy: 34284/34799 (99%)
#
#
# Validation set: Average loss: 2.8875, Accuracy: 4329/4410 (98%)

# %%
def test():
  model.eval()
  correct = 0
  for data, target in test_loader:
      with torch.no_grad():
          data, target = Variable(data), Variable(target)
          if use_gpu:
              data = data.cuda()
              target = target.cuda()
          output = model(data)
          pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
          f1=f1_score(target.long().cpu().numpy(),pred.cpu().numpy(),average="macro")
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

  print('\nTest set: F1-score: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
      f1, correct, len(test_loader.dataset),
      100. * correct / len(test_loader.dataset)))

# %%
test()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# Test set: F1-score: 0.9557, Accuracy: 12252/12630 (97%)

# %% [markdown]
# # **Visualizing STN**

# %%
for i, (data,target) in enumerate(train_loader):
  break
model.eval()
a = data[:,:,:,:].detach()
b = model.stn(data[:,:,:,:].cuda()).cpu().detach()[:,:,:,:]
c = target.long()

def norm (a):
    a = (a-a.min())
    a/=(a.max())
    return a+0.00001


num=5
plt.figure(figsize=(10,2*num))
for i in range(num):
  a[i]=norm(a[i])
  b[i]=norm(b[i])
  plt.subplot(num,2,i*2+1)
  plt.imshow(a[i].permute(1,2,0))
  plt.subplot(num,2,i*2+2)
  plt.imshow(b[i].permute(1,2,0))
plt.tight_layout(pad=0, h_pad=0, w_pad=0)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # **Uncertainty Analysis**

# %% [markdown]
# Histogram of confidence estimates for correct, wrong classifications, and also for OoD samples

# %%
kernel_distace_normal,kernel_distace_wrong,kernel_distace_ood = [],[],[]
model.eval()

e=2
with torch.no_grad():
  for _,(data, target) in enumerate(test_loader):
    output = model(data.cuda())
    output = output.cpu()
    pred = output.argmax(1)
  ood = data + e*torch.randn(data.shape)
  new_output = model(ood.cuda())
  new_output = new_output.cpu();
  newpred = new_output.argmax(1)

for i in range (len(target)):
  if target[i] == pred [i]:
    kernel_distace_normal.append(output[i].max(0)[0].item())
  else:
    kernel_distace_wrong.append(output[i].max(0)[0].item())
kernel_distace_ood = new_output.max(1)[0].tolist()

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
n, bins, patches = plt.hist(x=[kernel_distace_normal,kernel_distace_ood], bins='auto', color=['#22FF22','#2222FF'])
plt.xlabel("Confidence"); plt.ylabel("freq"); plt.title("Confidence Histogram")
plt.legend(['Correct','OoD'],loc='upper left')
plt.subplot(1,2,2)
n, bins, patches = plt.hist(x=[kernel_distace_wrong], bins='auto', color=['#FF2222'])
plt.xlabel("Confidence"); plt.ylabel("freq"); plt.title("Confidence Histogram")
plt.legend(['Wrong'],loc='upper left')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# Class Estimates for epistemic and aleatoric uncertainties

# %%
model.eval()
with torch.no_grad():
  for _,(data, target) in enumerate(test_loader):
    output = model(data.cuda())
    output = output.cpu(); 
    sigma = model.sigma.cpu()
    target = target.long()

epistemic = np.empty((n_classes, 0)).tolist()
aleatoric = np.empty((n_classes, 0)).tolist()
for i in range (len(target)):
  epistemic[target[i].item()].append(output[i].max(0)[0].item())
  aleatoric[target[i].item()].append(sigma[i].item())
for i in range (n_classes):
  epistemic[i] = np.array(epistemic[i]).mean()
  aleatoric[i] = np.array(aleatoric[i]).mean()


x = np.arange(1,n_classes+1)
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
plt.plot(x, epistemic, label = "Epistemic")
plt.xlabel("class"); plt.ylabel("Average Confidence"); plt.title("Confidence per class");
plt.legend()

plt.subplot(1,2,2) 
plt.plot(x, aleatoric, label = "Aleatoric") 
plt.xlabel("class"); plt.ylabel("Average Noise"); plt.title("Confidence per class");
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "

# %% [markdown]
# Show uncertainties per Sample

# %%
def norm (a):
    a = (a-a.min())
    a/=(a.max()+0.00000001)
    return a

e=1
for i, (data,target) in enumerate(train_loader):
  break
sample = data[0]+e*torch.rand(data[0].shape)
plt.imshow(norm(sample).permute(1,2,0))
plt.show()

model.eval()
output = model(sample.view(1,3,32,32).cuda()).cpu().view(-1)
epistemic, aleatoric = output.max(0)[0].item(), model.sigma[0].item()
print("uncertainty = {:.3f}, noise = {:.3f}".format(epistemic, aleatoric))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# uncertainty = 0.992, noise = 0.571
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3888: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3826: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
